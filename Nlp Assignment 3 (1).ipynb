# %%
import nltk
nltk.download('names')
from nltk.corpus import names
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\mohit\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!

# %%
# Split Names Corpus into training, dev-test, and test sets
names = ([(name, 'male') for name in names.words('male.txt')] +
         [(name, 'female') for name in names.words('female.txt')])

import random
random.shuffle(names)

test_names = names[:500]
devtest_names = names[500:1000]
train_names = names[1000:]

# %%
test_set
# Out:
# [({'suffix1': 'e', 'suffix2': 'ne', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'Jo', 'length': 8, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'gi', 'length': 4, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy', 'length': 5, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 7, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'sy', 'length': 6, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd', 'length': 7, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 5, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee', 'length': 8, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'th', 'length': 8, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy', 'length': 4, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 9, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 6, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd', 'length': 6, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'fy', 'length': 5, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 4, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 5, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'Al', 'length': 2, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 7, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'bi', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'rs', 'length': 4, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ci', 'length': 4, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 7, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ga', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'or', 'length': 6, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny', 'length': 5, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 5, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'zy', 'length': 5, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee', 'length': 7, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir', 'length': 5, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 8, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ba', 'length': 5, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch', 'length': 7, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 9, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 8, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'b', 'suffix2': 'yb', 'length': 3, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 6, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 5, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 5, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah', 'length': 7, 'first_letter': 'W'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 9, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'ko', 'length': 5, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 6, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io', 'length': 7, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 10, 'first_letter': 'W'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 6, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 10, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll', 'length': 5, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay', 'length': 9, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 4, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 6, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee', 'length': 6, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ga', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 7, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 7, 'first_letter': 'V'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'us', 'length': 5, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry', 'length': 11, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 5, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 4, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'to', 'length': 7, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny', 'length': 5, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 6, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny', 'length': 5, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 5, 'first_letter': 'U'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 4, 'first_letter': 'Z'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'se', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'Jo', 'length': 2, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ma', 'length': 9, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir', 'length': 5, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 7, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld', 'length': 6, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd', 'length': 4, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ar', 'length': 5, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'ar', 'length': 6, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'as', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 9, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'io', 'length': 6, 'first_letter': 'N'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot', 'length': 6, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 8, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 6, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd', 'length': 6, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'ok', 'length': 9, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 5, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 5, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ki', 'length': 5, 'first_letter': 'V'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'de', 'length': 4, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'cy', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 7, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ki', 'length': 4, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 5, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'vy', 'length': 5, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ph', 'length': 6, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 8, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 9, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'fy', 'length': 5, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'sy', 'length': 4, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 5, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 6, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 8, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 5, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 6, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ae', 'length': 3, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 6, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'f', 'suffix2': 'lf', 'length': 6, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee', 'length': 8, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 5, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 7, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 7, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'ld', 'length': 6, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'Y'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 7, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 6, 'first_letter': 'Q'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'il', 'length': 5, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ca', 'length': 9, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 7, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri', 'length': 4, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir', 'length': 4, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'xy', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 9, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 8, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd', 'length': 6, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'se', 'length': 5, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 4, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'ud', 'length': 6, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 10, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'us', 'length': 9, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll', 'length': 8, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 've', 'length': 5, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 9, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 5, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 8, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 4, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 10, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn', 'length': 6, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 8, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'Z'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 5, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'v', 'suffix2': 'av', 'length': 6, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 3, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 8, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 5, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ke', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 6, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 8, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'st', 'length': 6, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'lo', 'length': 8, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'go', 'length': 4, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'tr', 'length': 5, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'og', 'length': 3, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 6, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 6, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 5, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'or', 'length': 6, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 8, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'll', 'length': 4, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 5, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 7, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 7, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd', 'length': 8, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'W'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 4, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'f', 'suffix2': 'ff', 'length': 4, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi', 'length': 4, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch', 'length': 4, 'first_letter': 'Z'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot', 'length': 8, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'mo', 'length': 7, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 7, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'un', 'length': 5, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'k', 'suffix2': 'rk', 'length': 5, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 7, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 7, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 6, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni', 'length': 5, 'first_letter': 'V'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'go', 'length': 5, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 7, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ki', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'es', 'length': 6, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 6, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'ul', 'length': 4, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 7, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 6, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'm', 'suffix2': 'em', 'length': 4, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah', 'length': 7, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'rt', 'length': 4, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 7, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'fa', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy', 'length': 5, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ke', 'length': 5, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd', 'length': 7, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 7, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'w', 'suffix2': 'ew', 'length': 3, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 7, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'am', 'length': 5, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'za', 'length': 7, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'al', 'length': 5, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 6, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn', 'length': 3, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'w', 'suffix2': 'ew', 'length': 10, 'first_letter': 'B'},
#   'male'),
#  ({'suffix1': 'h', 'suffix2': 'gh', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'w', 'suffix2': 'ow', 'length': 6, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're', 'length': 8, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'il', 'length': 4, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'pe', 'length': 6, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ed', 'length': 4, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ke', 'length': 6, 'first_letter': 'U'},
#   'female'),
#  ({'suffix1': 'm', 'suffix2': 'em', 'length': 4, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn', 'length': 8, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 8, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'es', 'length': 8, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'di', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'rt', 'length': 7, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 5, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 4, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ri', 'length': 4, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn', 'length': 7, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'gh', 'length': 7, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 5, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty', 'length': 7, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty', 'length': 7, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 4, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 4, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 3, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya', 'length': 6, 'first_letter': 'Z'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah', 'length': 6, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ge', 'length': 4, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'by', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 7, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni', 'length': 5, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ea', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 5, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'vi', 'length': 3, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 8, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 've', 'length': 3, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'm', 'suffix2': 'am', 'length': 7, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er', 'length': 6, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'ls', 'length': 4, 'first_letter': 'N'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'di', 'length': 7, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'li', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 7, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 3, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay', 'length': 4, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'lt', 'length': 4, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 8, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 8, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 6, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 7, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 7, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 6, 'first_letter': 'W'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 7, 'first_letter': 'Z'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay', 'length': 4, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 8, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'li', 'length': 5, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'r', 'suffix2': 'er', 'length': 6, 'first_letter': 'R'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 4, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'me', 'length': 5, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'by', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'z', 'suffix2': 'nz', 'length': 4, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'O'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 7, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 4, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 9, 'first_letter': 'N'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 8, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'si', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 4, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 4, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'th', 'length': 5, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'p', 'suffix2': 'op', 'length': 8, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 10, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 4, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'im', 'length': 7, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 8, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 7, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'm', 'suffix2': 'am', 'length': 7, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 5, 'first_letter': 'V'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'rn', 'length': 5, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 4, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'gh', 'length': 7, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd', 'length': 7, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot', 'length': 5, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn', 'length': 8, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'ed', 'length': 6, 'first_letter': 'W'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'es', 'length': 4, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'oe', 'length': 6, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 4, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'li', 'length': 7, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 6, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 6, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 8, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 8, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 6, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 6, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 7, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'se', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'al', 'length': 8, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'do', 'length': 7, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll', 'length': 8, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'ck', 'length': 4, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'he', 'length': 15, 'first_letter': 'J'},
#   'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 7, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'm', 'suffix2': 'Em', 'length': 2, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn', 'length': 8, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 5, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni', 'length': 5, 'first_letter': 'V'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ma', 'length': 7, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra', 'length': 7, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ca', 'length': 7, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'cy', 'length': 9, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 4, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'di', 'length': 4, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'be', 'length': 3, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'I'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty', 'length': 5, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 6, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'o', 'suffix2': 'do', 'length': 4, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ba', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'gt', 'length': 5, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us', 'length': 9, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ar', 'length': 4, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'li', 'length': 5, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 9, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'g', 'suffix2': 'rg', 'length': 5, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 7, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'us', 'length': 8, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 7, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 5, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 4, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 6, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 4, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd', 'length': 7, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ti', 'length': 5, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 8, 'first_letter': 'N'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'A'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 8, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 8, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch', 'length': 5, 'first_letter': 'N'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'mi', 'length': 4, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 5, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic', 'length': 8, 'first_letter': 'F'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha', 'length': 7, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ue', 'length': 7, 'first_letter': 'R'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 've', 'length': 5, 'first_letter': 'O'},
#   'female'),
#  ({'suffix1': 'c', 'suffix2': 'uc', 'length': 8, 'first_letter': 'J'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'i', 'suffix2': 'li', 'length': 5, 'first_letter': 'H'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 9, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'gy', 'length': 5, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ke', 'length': 8, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 7, 'first_letter': 'S'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 7, 'first_letter': 'Q'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld', 'length': 6, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en', 'length': 10, 'first_letter': 'M'},
#   'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 5, 'first_letter': 'P'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te', 'length': 7, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ri', 'length': 5, 'first_letter': 'G'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'in', 'length': 6, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'be', 'length': 4, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er', 'length': 5, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'l', 'suffix2': 'rl', 'length': 3, 'first_letter': 'E'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 're', 'length': 5, 'first_letter': 'T'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el', 'length': 7, 'first_letter': 'G'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'id', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'n', 'suffix2': 'an', 'length': 3, 'first_letter': 'H'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 6, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'os', 'length': 4, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie', 'length': 5, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 6, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa', 'length': 7, 'first_letter': 'T'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce', 'length': 8, 'first_letter': 'C'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on', 'length': 5, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah', 'length': 7, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'tt', 'length': 7, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 7, 'first_letter': 'Q'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da', 'length': 7, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 't', 'suffix2': 'nt', 'length': 5, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 9, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'my', 'length': 6, 'first_letter': 'S'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'na', 'length': 5, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny', 'length': 5, 'first_letter': 'L'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'fe', 'length': 5, 'first_letter': 'K'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha', 'length': 6, 'first_letter': 'E'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta', 'length': 7, 'first_letter': 'B'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy', 'length': 5, 'first_letter': 'W'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 7, 'first_letter': 'M'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey', 'length': 6, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic', 'length': 7, 'first_letter': 'D'}, 'male'),
#  ({'suffix1': 'z', 'suffix2': 'ez', 'length': 7, 'first_letter': 'X'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'th', 'length': 8, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 7, 'first_letter': 'M'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'is', 'length': 7, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'la', 'length': 4, 'first_letter': 'B'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne', 'length': 8, 'first_letter': 'J'},
#   'female'),
#  ({'suffix1': 'e', 'suffix2': 'se', 'length': 5, 'first_letter': 'L'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia', 'length': 5, 'first_letter': 'D'},
#   'female'),
#  ({'suffix1': 's', 'suffix2': 'us', 'length': 8, 'first_letter': 'A'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le', 'length': 8, 'first_letter': 'C'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'py', 'length': 5, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'h', 'suffix2': 'th', 'length': 5, 'first_letter': 'F'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 6, 'first_letter': 'K'},
#   'female'),
#  ({'suffix1': 'a', 'suffix2': 'pa', 'length': 7, 'first_letter': 'P'},
#   'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly', 'length': 5, 'first_letter': 'M'},
#   'female')]

# %%
devtest_names
# Out:
# [('Ephrem', 'male'),
#  ('Kare', 'female'),
#  ('Grethel', 'female'),
#  ('Alvin', 'male'),
#  ('Aleda', 'female'),
#  ('Marci', 'female'),
#  ('Ilene', 'female'),
#  ('Dorisa', 'female'),
#  ('Fox', 'male'),
#  ('Elaine', 'female'),
#  ('Daniella', 'female'),
#  ('Giselle', 'female'),
#  ('Celene', 'female'),
#  ('Bethena', 'female'),
#  ('Isa', 'male'),
#  ('Diamond', 'female'),
#  ('Allie', 'female'),
#  ('Sisely', 'female'),
#  ('Wyatan', 'male'),
#  ('Blythe', 'female'),
#  ('Terza', 'female'),
#  ('Henri', 'male'),
#  ('Eliot', 'male'),
#  ('Hank', 'male'),
#  ('John-Patrick', 'male'),
#  ('Albert', 'male'),
#  ('Osmond', 'male'),
#  ('Kent', 'male'),
#  ('Barney', 'male'),
#  ('Esau', 'male'),
#  ('Peria', 'female'),
#  ('Nicole', 'female'),
#  ('Michel', 'male'),
#  ('Natalie', 'female'),
#  ('Salvidor', 'male'),
#  ('Clay', 'male'),
#  ('Florie', 'female'),
#  ('Betti', 'female'),
#  ('Lena', 'female'),
#  ('Georgia', 'male'),
#  ('Tommy', 'female'),
#  ('Berri', 'female'),
#  ('Anna', 'female'),
#  ('Andriana', 'female'),
#  ('Meier', 'male'),
#  ('Erin', 'female'),
#  ('Chaunce', 'male'),
#  ('Flo', 'female'),
#  ('Orion', 'male'),
#  ('Roderigo', 'male'),
#  ('Davy', 'male'),
#  ('Robyn', 'female'),
#  ('Elmore', 'male'),
#  ('Deirdre', 'female'),
#  ('Abel', 'male'),
#  ('Joyce', 'female'),
#  ('Reynolds', 'male'),
#  ('Maryanne', 'female'),
#  ('Coleen', 'female'),
#  ('Merrile', 'female'),
#  ('Niall', 'male'),
#  ('Gordon', 'male'),
#  ('Osborne', 'male'),
#  ('Heinrich', 'male'),
#  ('Leonanie', 'female'),
#  ('Shari', 'female'),
#  ('Polly', 'female'),
#  ('Orson', 'male'),
#  ('Reginauld', 'male'),
#  ('Kimball', 'male'),
#  ('Rosanne', 'female'),
#  ('Karsten', 'male'),
#  ('Tabbatha', 'female'),
#  ('Dael', 'female'),
#  ('Kelcie', 'female'),
#  ('Allan', 'male'),
#  ('Gregorio', 'male'),
#  ('Taddeo', 'male'),
#  ('Lloyd', 'male'),
#  ('Joshuah', 'male'),
#  ('Kris', 'female'),
#  ('Leah', 'female'),
#  ('Radcliffe', 'male'),
#  ('Alexandra', 'female'),
#  ('Wendie', 'female'),
#  ('Baird', 'male'),
#  ('Towney', 'male'),
#  ('Kara', 'female'),
#  ('Ruperto', 'male'),
#  ('Freddi', 'female'),
#  ('Tharen', 'male'),
#  ('Harlan', 'male'),
#  ('Antonin', 'male'),
#  ('Chet', 'male'),
#  ('Raye', 'female'),
#  ('Amanda', 'female'),
#  ('Aime', 'female'),
#  ('Loni', 'female'),
#  ('Amelia', 'female'),
#  ('Dulci', 'female'),
#  ('Stephi', 'female'),
#  ('Niels', 'male'),
#  ('Garvey', 'male'),
#  ('Bentley', 'male'),
#  ('Kassia', 'female'),
#  ('Shayla', 'female'),
#  ('Bayard', 'male'),
#  ('Laurena', 'female'),
#  ('Hasty', 'male'),
#  ('Fanni', 'female'),
#  ('Grissel', 'female'),
#  ('Gussie', 'female'),
#  ('Cecilla', 'female'),
#  ('Elsi', 'female'),
#  ('Leonora', 'female'),
#  ('Zelma', 'female'),
#  ('Huntley', 'male'),
#  ('Marita', 'female'),
#  ('Ugo', 'male'),
#  ('Marion', 'male'),
#  ('Kathe', 'female'),
#  ('Werner', 'male'),
#  ('Gale', 'female'),
#  ('Rebecka', 'female'),
#  ('Brea', 'female'),
#  ('Rawley', 'male'),
#  ('Franni', 'female'),
#  ('Darren', 'male'),
#  ('Frederico', 'male'),
#  ('Chas', 'male'),
#  ('Lauree', 'female'),
#  ('Elmira', 'female'),
#  ('Barret', 'male'),
#  ('Fraser', 'male'),
#  ('Noe', 'male'),
#  ('Stillman', 'male'),
#  ('Steve', 'male'),
#  ('Reta', 'female'),
#  ('Lanny', 'male'),
#  ('Aurea', 'female'),
#  ('Lynn', 'female'),
#  ('Merle', 'female'),
#  ('Norry', 'female'),
#  ('Reggie', 'male'),
#  ('Harri', 'female'),
#  ('Tara', 'female'),
#  ('Quincey', 'male'),
#  ('Jannel', 'female'),
#  ('Veronika', 'female'),
#  ('Duffie', 'male'),
#  ('Rodina', 'female'),
#  ('Tuesday', 'female'),
#  ('Vanni', 'female'),
#  ('Kathleen', 'female'),
#  ('Sheela', 'female'),
#  ('Nigel', 'male'),
#  ('Lavina', 'female'),
#  ('Evelyn', 'male'),
#  ('Gratia', 'female'),
#  ('Linnell', 'female'),
#  ('Ahmet', 'male'),
#  ('Susette', 'female'),
#  ('Hilliary', 'female'),
#  ('Rosy', 'female'),
#  ('Claudine', 'female'),
#  ('Nancee', 'female'),
#  ('Raoul', 'male'),
#  ('Aurelia', 'female'),
#  ('Tan', 'male'),
#  ('Cariotta', 'female'),
#  ('Johannes', 'male'),
#  ('Rey', 'female'),
#  ('Edee', 'female'),
#  ('Cass', 'male'),
#  ('Ez', 'male'),
#  ('Bethina', 'female'),
#  ('Denys', 'female'),
#  ('Roxy', 'female'),
#  ('Bertina', 'female'),
#  ('Keil', 'male'),
#  ('Julee', 'female'),
#  ('Edwina', 'female'),
#  ('Zorana', 'female'),
#  ('Monty', 'male'),
#  ('Minny', 'female'),
#  ('Martie', 'male'),
#  ('Ajai', 'male'),
#  ('Kessiah', 'female'),
#  ('Billie', 'female'),
#  ('Stormie', 'female'),
#  ('Waneta', 'female'),
#  ('Phip', 'male'),
#  ('Major', 'male'),
#  ('Albertine', 'female'),
#  ('Auguste', 'female'),
#  ('Adnan', 'male'),
#  ('Charlene', 'female'),
#  ('Carson', 'male'),
#  ('Maybelle', 'female'),
#  ('Cooper', 'male'),
#  ('Lisha', 'female'),
#  ('Umberto', 'male'),
#  ('Philippe', 'female'),
#  ('Kevan', 'male'),
#  ('Scotti', 'male'),
#  ('Whitney', 'female'),
#  ('Francesmary', 'female'),
#  ('Esmeralda', 'female'),
#  ('Nilson', 'male'),
#  ('Jena', 'female'),
#  ('Ric', 'male'),
#  ('Carmelia', 'female'),
#  ('Lilla', 'female'),
#  ('Aleecia', 'female'),
#  ('Zonda', 'female'),
#  ('Kelly', 'male'),
#  ('Hersch', 'male'),
#  ('Philip', 'male'),
#  ('Jenica', 'female'),
#  ('Elenore', 'female'),
#  ('Gene', 'male'),
#  ('Nathanael', 'male'),
#  ('Brandise', 'female'),
#  ('Tanney', 'male'),
#  ('Minette', 'female'),
#  ('Sigfrid', 'male'),
#  ('Willem', 'male'),
#  ('Lambert', 'male'),
#  ('Bev', 'female'),
#  ('Sibby', 'female'),
#  ('Morrie', 'male'),
#  ('Johanna', 'female'),
#  ('Celestina', 'female'),
#  ('Blare', 'male'),
#  ('Aristotle', 'male'),
#  ('Edithe', 'female'),
#  ('Harli', 'female'),
#  ('Hercule', 'male'),
#  ('Nikki', 'female'),
#  ('Oren', 'male'),
#  ('Fidel', 'male'),
#  ('Havivah', 'female'),
#  ('Shayne', 'female'),
#  ('Darcy', 'male'),
#  ('Jelene', 'female'),
#  ('Woochang', 'male'),
#  ('Maxi', 'female'),
#  ('Voltaire', 'male'),
#  ('Julina', 'female'),
#  ('Maggy', 'female'),
#  ('Phoebe', 'female'),
#  ('Dahlia', 'female'),
#  ('Ede', 'female'),
#  ('Catherina', 'female'),
#  ('Mavra', 'female'),
#  ('Wilhelmina', 'female'),
#  ('Madella', 'female'),
#  ('Domenico', 'male'),
#  ('Gerard', 'male'),
#  ('Laraine', 'female'),
#  ('Kathy', 'female'),
#  ('Guglielma', 'female'),
#  ('Karolina', 'female'),
#  ('Sher', 'female'),
#  ('Gretel', 'female'),
#  ('Corina', 'female'),
#  ('Britte', 'female'),
#  ('Flower', 'female'),
#  ('Siana', 'female'),
#  ('Tre', 'male'),
#  ('Laetitia', 'female'),
#  ('Roy', 'male'),
#  ('Berti', 'female'),
#  ('Salim', 'male'),
#  ('Sivert', 'male'),
#  ('Ioana', 'female'),
#  ('Abner', 'male'),
#  ('Bearnard', 'male'),
#  ('Isidore', 'male'),
#  ('Maggee', 'female'),
#  ('Tommy', 'male'),
#  ('Murielle', 'female'),
#  ('Pierette', 'female'),
#  ('Cristal', 'female'),
#  ('Anastassia', 'female'),
#  ('Bartholomeo', 'male'),
#  ('Temple', 'male'),
#  ('Danyelle', 'female'),
#  ('Donica', 'female'),
#  ('Evey', 'female'),
#  ('Jenda', 'female'),
#  ('Jodi', 'male'),
#  ('Sigrid', 'female'),
#  ('Wittie', 'male'),
#  ('Sibley', 'female'),
#  ('Lemmy', 'male'),
#  ('Melli', 'female'),
#  ('Davidson', 'male'),
#  ('Farand', 'female'),
#  ('Albina', 'female'),
#  ('Jesse', 'male'),
#  ('Jud', 'male'),
#  ('Dacie', 'female'),
#  ('Mirabelle', 'female'),
#  ('Ellyn', 'female'),
#  ('Matthiew', 'male'),
#  ('Vail', 'male'),
#  ('Henriette', 'female'),
#  ('Antonina', 'female'),
#  ('TeresaAnne', 'female'),
#  ('Jeannette', 'female'),
#  ('Patricio', 'male'),
#  ('Hewitt', 'male'),
#  ('Honey', 'female'),
#  ('Zarah', 'female'),
#  ('Ninnette', 'female'),
#  ('Olivie', 'female'),
#  ('Kimberli', 'female'),
#  ('Roberto', 'male'),
#  ('Doti', 'female'),
#  ('Sadella', 'female'),
#  ('Tania', 'female'),
#  ('Micki', 'female'),
#  ('Pamela', 'female'),
#  ('Allyce', 'female'),
#  ('Juliann', 'female'),
#  ('Marvin', 'male'),
#  ('Park', 'male'),
#  ('Rubia', 'female'),
#  ('Joly', 'female'),
#  ('Eustace', 'male'),
#  ('Winford', 'male'),
#  ('Tybalt', 'male'),
#  ('Derron', 'male'),
#  ('Annetta', 'female'),
#  ('Helli', 'female'),
#  ('Ericka', 'female'),
#  ('Teddi', 'female'),
#  ('Cosette', 'female'),
#  ('Eleanor', 'female'),
#  ('Penrod', 'male'),
#  ('Davis', 'male'),
#  ('Kayle', 'female'),
#  ('Leorah', 'female'),
#  ('Pieter', 'male'),
#  ('Evita', 'female'),
#  ('Winnah', 'female'),
#  ('Leonid', 'male'),
#  ('Town', 'male'),
#  ('Waldon', 'male'),
#  ('Anni', 'female'),
#  ('Gwyneth', 'female'),
#  ('Nicolina', 'female'),
#  ('Neddy', 'male'),
#  ('Thebault', 'male'),
#  ('Constantinos', 'male'),
#  ('Nevin', 'male'),
#  ('Franz', 'male'),
#  ('Jimmie', 'male'),
#  ('Kit', 'female'),
#  ('Janaye', 'female'),
#  ('Butch', 'male'),
#  ('Ericha', 'female'),
#  ('Gabe', 'male'),
#  ('Emmie', 'female'),
#  ('Doll', 'female'),
#  ('Mortimer', 'male'),
#  ('Jodie', 'female'),
#  ('Emelyne', 'female'),
#  ('Fredrick', 'male'),
#  ('Lil', 'female'),
#  ('Olivia', 'female'),
#  ('Clareta', 'female'),
#  ('Tiff', 'female'),
#  ('Julian', 'male'),
#  ('Jacynth', 'female'),
#  ('Malanie', 'female'),
#  ('Carli', 'female'),
#  ('Margaretta', 'female'),
#  ('Prentiss', 'male'),
#  ('Leticia', 'female'),
#  ('Corrie', 'male'),
#  ('Ross', 'male'),
#  ('Way', 'male'),
#  ('Hillel', 'male'),
#  ('Duncan', 'male'),
#  ('Bernadine', 'female'),
#  ('Arleyne', 'female'),
#  ('Eilis', 'female'),
#  ('Leia', 'female'),
#  ('Marlon', 'male'),
#  ('Goldy', 'female'),
#  ('Minni', 'female'),
#  ('Barthel', 'male'),
#  ('Alexei', 'male'),
#  ('Becka', 'female'),
#  ('Alli', 'female'),
#  ('Goldina', 'female'),
#  ('Annelise', 'female'),
#  ('Jori', 'female'),
#  ('Norm', 'male'),
#  ('Jobye', 'female'),
#  ('Mariann', 'female'),
#  ('Nevil', 'male'),
#  ('Brett', 'female'),
#  ('Grazia', 'female'),
#  ('Thomasin', 'female'),
#  ('Ibby', 'female'),
#  ('Fonsie', 'male'),
#  ('Gabriele', 'male'),
#  ('Melita', 'female'),
#  ('Traci', 'female'),
#  ('Corwin', 'male'),
#  ('Marji', 'female'),
#  ('Flossie', 'female'),
#  ('Clo', 'female'),
#  ('Rosabel', 'female'),
#  ('Mel', 'male'),
#  ('Cortese', 'male'),
#  ('Shirleen', 'female'),
#  ('Charlie', 'male'),
#  ('Arielle', 'female'),
#  ('Melinda', 'female'),
#  ('Hal', 'male'),
#  ('Rollin', 'male'),
#  ('Kylila', 'female'),
#  ('Margret', 'female'),
#  ('Harriet', 'female'),
#  ('Abby', 'male'),
#  ('Tressa', 'female'),
#  ('Felecia', 'female'),
#  ('Galina', 'female'),
#  ('Pepita', 'female'),
#  ('Babette', 'female'),
#  ('Udale', 'male'),
#  ('Karoly', 'female'),
#  ('Heywood', 'male'),
#  ('Berni', 'female'),
#  ('Aeriel', 'female'),
#  ('Melva', 'female'),
#  ('Carolee', 'female'),
#  ('Hulda', 'female'),
#  ('Salvatore', 'male'),
#  ('Bryana', 'female'),
#  ('Duffy', 'male'),
#  ('Chantalle', 'female'),
#  ('Oriana', 'female'),
#  ('Patsy', 'male'),
#  ('Pepi', 'female'),
#  ('Mmarianne', 'female'),
#  ('Nonie', 'female'),
#  ('Corabelle', 'female'),
#  ('Nelson', 'male'),
#  ('Olivier', 'male'),
#  ('Aloysia', 'female'),
#  ('Darcie', 'female'),
#  ('Sid', 'male'),
#  ('Clara', 'female'),
#  ('Orelee', 'female'),
#  ('Xever', 'male'),
#  ('Merill', 'male'),
#  ('Sterling', 'male'),
#  ('Anastasia', 'female'),
#  ('Wash', 'male'),
#  ('Aurelie', 'female'),
#  ('Mac', 'male'),
#  ('Camellia', 'female'),
#  ('Darrel', 'male'),
#  ('Dayna', 'female'),
#  ('Kanya', 'female'),
#  ('Harriott', 'female'),
#  ('Cara', 'female'),
#  ('Clarette', 'female'),
#  ('Emmery', 'male'),
#  ('Bevvy', 'female'),
#  ('Shelagh', 'female'),
#  ('Roland', 'male'),
#  ('Noelle', 'female'),
#  ('Karola', 'female'),
#  ('Henryetta', 'female'),
#  ('Simonette', 'female'),
#  ('Dorri', 'female'),
#  ('Moss', 'male'),
#  ('Jewel', 'female'),
#  ('Bartolemo', 'male'),
#  ('Virgie', 'male'),
#  ('Adrian', 'male'),
#  ('Welby', 'male'),
#  ('Lita', 'female'),
#  ('Teodoro', 'male'),
#  ('Dido', 'female'),
#  ('Dolli', 'female'),
#  ('Jeanelle', 'female'),
#  ('Melanie', 'female'),
#  ('Ree', 'female'),
#  ('Bengt', 'male'),
#  ('Filia', 'female'),
#  ('Leon', 'male'),
#  ('Marie', 'female'),
#  ('Krishna', 'male')]

# %%
train_names
# Out:
# [('Jere', 'female'),
#  ('Farley', 'male'),
#  ('Ellie', 'female'),
#  ('Franky', 'male'),
#  ('Parrnell', 'male'),
#  ('Hyacinthia', 'female'),
#  ('Alden', 'male'),
#  ('Naomi', 'female'),
#  ('Renelle', 'female'),
#  ('Nedi', 'female'),
#  ('Phyllida', 'female'),
#  ('Lida', 'female'),
#  ('Hiralal', 'male'),
#  ('Curtis', 'male'),
#  ('Seline', 'female'),
#  ('Oralle', 'female'),
#  ('Leshia', 'female'),
#  ('Jo Ann', 'female'),
#  ('Ingeberg', 'female'),
#  ('Conrad', 'male'),
#  ('Forbes', 'male'),
#  ('Fitzgerald', 'male'),
#  ('Corissa', 'female'),
#  ('Jodie', 'male'),
#  ('Avrit', 'female'),
#  ('Griswold', 'male'),
#  ('Jasmina', 'female'),
#  ('Billie', 'male'),
#  ('Phillip', 'male'),
#  ('Randal', 'male'),
#  ('Robert', 'male'),
#  ('Dominick', 'male'),
#  ('Ulrick', 'male'),
#  ('Isidora', 'female'),
#  ('Donnajean', 'female'),
#  ('Agnese', 'female'),
#  ('Willette', 'female'),
#  ('Ike', 'female'),
#  ('Helene', 'female'),
#  ('Bathsheba', 'female'),
#  ('Toinette', 'female'),
#  ('Janessa', 'female'),
#  ('Nert', 'female'),
#  ('Darby', 'female'),
#  ('Brook', 'male'),
#  ('Windy', 'female'),
#  ('Alecia', 'female'),
#  ('Nelli', 'female'),
#  ('Minda', 'female'),
#  ('Katie', 'female'),
#  ('Tallie', 'male'),
#  ('Corrina', 'female'),
#  ('Daryn', 'female'),
#  ('Clea', 'female'),
#  ('Jemmy', 'female'),
#  ('Ramona', 'female'),
#  ('Sibilla', 'female'),
#  ('Dory', 'female'),
#  ('Grayce', 'female'),
#  ('Morten', 'male'),
#  ('Alanah', 'female'),
#  ('Joana', 'female'),
#  ('Blisse', 'female'),
#  ('Stace', 'female'),
#  ('Lavinia', 'female'),
#  ('Dixie', 'female'),
#  ('Jeff', 'male'),
#  ('Wilek', 'male'),
#  ('Raphaela', 'female'),
#  ('Grata', 'female'),
#  ('Tiana', 'female'),
#  ('Clayborne', 'male'),
#  ('Cesya', 'female'),
#  ('Adaline', 'female'),
#  ('Lonee', 'female'),
#  ('Mignonne', 'female'),
#  ('Glennis', 'female'),
#  ('Liza', 'female'),
#  ('Delmar', 'male'),
#  ('Adolph', 'male'),
#  ('Allys', 'female'),
#  ('Wandis', 'female'),
#  ('Marianne', 'female'),
#  ('Felisha', 'female'),
#  ('Tomi', 'female'),
#  ('Teodor', 'male'),
#  ('Isaac', 'male'),
#  ('Morena', 'female'),
#  ('Quint', 'male'),
#  ('Pavel', 'male'),
#  ('Nomi', 'female'),
#  ('Ashley', 'male'),
#  ('Randall', 'male'),
#  ('Jonathon', 'male'),
#  ('Lilly', 'female'),
#  ('Skipton', 'male'),
#  ('Tomkin', 'male'),
#  ('Latisha', 'female'),
#  ('Jayne', 'female'),
#  ('Smith', 'male'),
#  ('Alvira', 'female'),
#  ('Kristen', 'female'),
#  ('Nannette', 'female'),
#  ('Nat', 'male'),
#  ('Petronella', 'female'),
#  ('Filide', 'female'),
#  ('Nathanil', 'male'),
#  ('Terrance', 'male'),
#  ('Jacinthe', 'female'),
#  ('Dell', 'female'),
#  ('Roger', 'male'),
#  ('Elana', 'female'),
#  ('Bertha', 'female'),
#  ('Sussi', 'female'),
#  ('Claudelle', 'female'),
#  ('Leif', 'male'),
#  ('Laurella', 'female'),
#  ('Trever', 'male'),
#  ('Lurleen', 'female'),
#  ('Catharina', 'female'),
#  ('Netti', 'female'),
#  ('Sascha', 'female'),
#  ('Odelle', 'female'),
#  ('Rowe', 'female'),
#  ('Noreen', 'female'),
#  ('Nissy', 'female'),
#  ('Veronique', 'female'),
#  ('Estelle', 'female'),
#  ('Gianna', 'female'),
#  ('Harlie', 'female'),
#  ('Sander', 'male'),
#  ('Atlanta', 'female'),
#  ('Jonah', 'male'),
#  ('Kam', 'male'),
#  ('Denni', 'female'),
#  ('Gayle', 'female'),
#  ('Reeta', 'female'),
#  ('Jaclyn', 'female'),
#  ('Francine', 'female'),
#  ('Giacinta', 'female'),
#  ('Cheslie', 'female'),
#  ('Shanon', 'female'),
#  ('Kellen', 'female'),
#  ('Linoel', 'male'),
#  ('Maud', 'female'),
#  ('Chev', 'male'),
#  ('Kermie', 'male'),
#  ('Brittan', 'female'),
#  ('Clive', 'male'),
#  ('Ilise', 'female'),
#  ('Paul', 'male'),
#  ('Doe', 'female'),
#  ('Meara', 'female'),
#  ('Vaughan', 'male'),
#  ('Dorella', 'female'),
#  ('Correy', 'female'),
#  ('Donelle', 'female'),
#  ('Ashleigh', 'female'),
#  ('Florry', 'female'),
#  ('Timmy', 'male'),
#  ('Pepe', 'male'),
#  ('Kendall', 'male'),
#  ('Spense', 'male'),
#  ('Tedra', 'female'),
#  ('Sutherland', 'male'),
#  ('Barnabe', 'male'),
#  ('Egbert', 'male'),
#  ('Cathrin', 'female'),
#  ('Josephine', 'female'),
#  ('Nelia', 'female'),
#  ('Monroe', 'male'),
#  ('Zorine', 'female'),
#  ('Wenona', 'female'),
#  ('Ezekiel', 'male'),
#  ('Gilburt', 'male'),
#  ('Ami', 'female'),
#  ('Sarena', 'female'),
#  ('Zabrina', 'female'),
#  ('Chelsie', 'female'),
#  ('Scottie', 'male'),
#  ('Dickie', 'male'),
#  ('Bob', 'male'),
#  ('Lurette', 'female'),
#  ('Bjorne', 'male'),
#  ('Isahella', 'female'),
#  ('Martynne', 'female'),
#  ('Hedwig', 'female'),
#  ('Marilu', 'male'),
#  ('Larine', 'female'),
#  ('Emmet', 'male'),
#  ('Juditha', 'female'),
#  ('Gennifer', 'female'),
#  ('Katti', 'female'),
#  ('Maya', 'female'),
#  ('Joao', 'male'),
#  ('Lin', 'male'),
#  ('Francisca', 'female'),
#  ('Alice', 'female'),
#  ('Fay', 'female'),
#  ('Adriena', 'female'),
#  ('Jessy', 'female'),
#  ('Fayth', 'female'),
#  ('Darlene', 'female'),
#  ('Francois', 'male'),
#  ('Loretta', 'female'),
#  ('Kellen', 'male'),
#  ('Teri', 'female'),
#  ('Adoree', 'female'),
#  ('Daffie', 'female'),
#  ('Trace', 'female'),
#  ('Wilow', 'female'),
#  ('Staffard', 'male'),
#  ('Benito', 'male'),
#  ('Shela', 'female'),
#  ('Barrie', 'male'),
#  ('Anatola', 'female'),
#  ('Bradford', 'male'),
#  ('Maxwell', 'male'),
#  ('Gregor', 'male'),
#  ('Dee', 'female'),
#  ('Liliane', 'female'),
#  ('Coleman', 'male'),
#  ('Susanne', 'female'),
#  ('Didi', 'female'),
#  ('Glorianna', 'female'),
#  ('Vale', 'female'),
#  ('Darwin', 'male'),
#  ('Laurence', 'male'),
#  ('Ashlee', 'female'),
#  ('Pammi', 'female'),
#  ('Catha', 'female'),
#  ('Charmane', 'female'),
#  ('Huey', 'male'),
#  ('Stern', 'male'),
#  ('Thibaut', 'male'),
#  ('Geoffry', 'male'),
#  ('Bing', 'male'),
#  ('Sergent', 'male'),
#  ('Jessee', 'male'),
#  ('Celina', 'female'),
#  ('Kaiser', 'male'),
#  ('Beatriz', 'female'),
#  ('Hollis', 'male'),
#  ('Ricca', 'female'),
#  ('Archibold', 'male'),
#  ('Ilana', 'female'),
#  ('Heddi', 'female'),
#  ('Darice', 'female'),
#  ('Broderick', 'male'),
#  ('Rayner', 'male'),
#  ('Aeriell', 'female'),
#  ('Tessy', 'female'),
#  ('Esmerelda', 'female'),
#  ('Carlina', 'female'),
#  ('Vasili', 'male'),
#  ('Daryle', 'male'),
#  ('Angele', 'female'),
#  ('Teriann', 'female'),
#  ('Jeremiah', 'male'),
#  ('Garrott', 'male'),
#  ('Maryanna', 'female'),
#  ('Osgood', 'male'),
#  ('Rania', 'female'),
#  ('Alexis', 'male'),
#  ('Regan', 'male'),
#  ('Jameson', 'male'),
#  ('Arleta', 'female'),
#  ('Randolph', 'male'),
#  ('Lazaro', 'male'),
#  ('Caesar', 'male'),
#  ('Olle', 'male'),
#  ('Saxe', 'male'),
#  ('Josefa', 'female'),
#  ('Kamilah', 'female'),
#  ('Kip', 'male'),
#  ('Red', 'male'),
#  ('Thorpe', 'male'),
#  ('Westbrooke', 'male'),
#  ('Bellamy', 'female'),
#  ('Nicolea', 'female'),
#  ('Abe', 'male'),
#  ('Sanson', 'male'),
#  ('Valaree', 'female'),
#  ('Tamarah', 'female'),
#  ('Troy', 'male'),
#  ('Sybille', 'female'),
#  ('Somerset', 'male'),
#  ('Fidelia', 'female'),
#  ('Melania', 'female'),
#  ('Koral', 'female'),
#  ('Ardra', 'female'),
#  ('Moises', 'male'),
#  ('Aharon', 'male'),
#  ('Terrence', 'male'),
#  ('Katharyn', 'female'),
#  ('Corny', 'female'),
#  ('Winston', 'male'),
#  ('Imogene', 'female'),
#  ('Marni', 'female'),
#  ('Isabelita', 'female'),
#  ('Harmon', 'male'),
#  ('Shandie', 'female'),
#  ('Vivie', 'female'),
#  ('Timothea', 'female'),
#  ('Reuben', 'male'),
#  ('Northrop', 'male'),
#  ('Urson', 'male'),
#  ('Winslow', 'male'),
#  ('Ammamaria', 'female'),
#  ('Carolina', 'female'),
#  ('Carissa', 'female'),
#  ('Averil', 'female'),
#  ('Fiann', 'female'),
#  ('Nissa', 'female'),
#  ('Merla', 'female'),
#  ('Bonni', 'female'),
#  ('Shoshanna', 'female'),
#  ('Emmett', 'male'),
#  ('Therine', 'female'),
#  ('Derrin', 'male'),
#  ('Delinda', 'female'),
#  ('Edmond', 'male'),
#  ('Henka', 'female'),
#  ('Paula', 'female'),
#  ('Lawrence', 'male'),
#  ('Alma', 'female'),
#  ('Lira', 'female'),
#  ('Daniel', 'female'),
#  ('Dynah', 'female'),
#  ('Toby', 'female'),
#  ('Norri', 'female'),
#  ('Denice', 'female'),
#  ('Doretta', 'female'),
#  ('Anson', 'male'),
#  ('Fulvia', 'female'),
#  ('Maryann', 'female'),
#  ('Vina', 'female'),
#  ('Gerri', 'female'),
#  ('Carmen', 'female'),
#  ('Sibeal', 'female'),
#  ('Becca', 'female'),
#  ('Conan', 'male'),
#  ('Jewell', 'female'),
#  ('Lura', 'female'),
#  ('Wojciech', 'male'),
#  ('Burnaby', 'male'),
#  ('Ambur', 'female'),
#  ('Jillayne', 'female'),
#  ('Beowulf', 'male'),
#  ('Kerrin', 'female'),
#  ('Ethel', 'female'),
#  ('Carrissa', 'female'),
#  ('Pyotr', 'male'),
#  ('Robinett', 'female'),
#  ('Andreana', 'female'),
#  ('Cesar', 'male'),
#  ('Joseph', 'male'),
#  ('Darian', 'male'),
#  ('Bertie', 'female'),
#  ('Melisandra', 'female'),
#  ('Tibold', 'male'),
#  ('Mickey', 'male'),
#  ('Rodrique', 'male'),
#  ('Chester', 'male'),
#  ('Moses', 'male'),
#  ('Wilma', 'female'),
#  ('Fedora', 'female'),
#  ('Leroy', 'male'),
#  ('Thaxter', 'male'),
#  ('Delilah', 'female'),
#  ('Tatiana', 'female'),
#  ('Edna', 'female'),
#  ('Prisca', 'female'),
#  ('Yevette', 'female'),
#  ('Eolanda', 'female'),
#  ('Julienne', 'female'),
#  ('Lindy', 'female'),
#  ('Charlot', 'female'),
#  ('Kristopher', 'male'),
#  ('Bryn', 'female'),
#  ('Ashli', 'female'),
#  ('Gardener', 'male'),
#  ('Billy', 'male'),
#  ('Emmit', 'male'),
#  ('Page', 'female'),
#  ('Brody', 'male'),
#  ('Giordano', 'male'),
#  ('Brook', 'female'),
#  ('Leodora', 'female'),
#  ('Pat', 'male'),
#  ('Nadya', 'female'),
#  ('Mersey', 'female'),
#  ('Roch', 'female'),
#  ('Tiffie', 'female'),
#  ('Bronson', 'male'),
#  ('Magdalen', 'female'),
#  ('Bessy', 'female'),
#  ('Moshe', 'male'),
#  ('Sioux', 'female'),
#  ('Aidan', 'female'),
#  ('Tonnie', 'male'),
#  ('Sloane', 'male'),
#  ('Pollyanna', 'female'),
#  ('Tally', 'male'),
#  ('Belia', 'female'),
#  ('Beverie', 'female'),
#  ('Gallagher', 'male'),
#  ('Amber', 'female'),
#  ('Pauli', 'female'),
#  ('Waite', 'male'),
#  ('Leoline', 'female'),
#  ('Barton', 'male'),
#  ('Coraline', 'female'),
#  ('Prissie', 'female'),
#  ('Trevor', 'male'),
#  ('Aditya', 'male'),
#  ('Dorolisa', 'female'),
#  ('Kordula', 'female'),
#  ('Fanchon', 'female'),
#  ('Nadine', 'female'),
#  ('Archy', 'male'),
#  ('Ebba', 'female'),
#  ('Lurlene', 'female'),
#  ('Alfie', 'female'),
#  ('Olwen', 'female'),
#  ('Imogen', 'female'),
#  ('Masha', 'female'),
#  ('Paulita', 'female'),
#  ('Missy', 'female'),
#  ('Josephus', 'male'),
#  ('Mairead', 'female'),
#  ('Stew', 'male'),
#  ('Addie', 'male'),
#  ('Brandice', 'female'),
#  ('Sue-elle', 'female'),
#  ('Wendeline', 'female'),
#  ('Perri', 'female'),
#  ('Margy', 'female'),
#  ('Nata', 'female'),
#  ('Ingrid', 'female'),
#  ('Othilia', 'female'),
#  ('Sarene', 'female'),
#  ('Farra', 'female'),
#  ('Wilt', 'male'),
#  ('Abbie', 'female'),
#  ('Cappella', 'female'),
#  ('Maury', 'male'),
#  ('Gerry', 'female'),
#  ('Ansley', 'female'),
#  ('Carly', 'female'),
#  ('Danit', 'female'),
#  ('Ceciley', 'female'),
#  ('Charleton', 'male'),
#  ('Hannibal', 'female'),
#  ('Nola', 'female'),
#  ('Fredericka', 'female'),
#  ('Friedrich', 'male'),
#  ('Lily', 'female'),
#  ('Simon', 'male'),
#  ('Calhoun', 'male'),
#  ('Leona', 'female'),
#  ('Arthur', 'male'),
#  ('Doris', 'female'),
#  ('Amelina', 'female'),
#  ('Ham', 'male'),
#  ('Konstance', 'female'),
#  ('Loren', 'male'),
#  ('Greer', 'female'),
#  ('Brandon', 'male'),
#  ('Gisele', 'female'),
#  ('Cathee', 'female'),
#  ('Farrand', 'female'),
#  ('Stefania', 'female'),
#  ('Susi', 'female'),
#  ('Flore', 'female'),
#  ('Laurene', 'female'),
#  ('Ozzy', 'male'),
#  ('Marmaduke', 'male'),
#  ('Olva', 'female'),
#  ('Amadeus', 'male'),
#  ('Bailie', 'male'),
#  ('Rozanne', 'female'),
#  ('Maire', 'female'),
#  ('Madlin', 'female'),
#  ('Melodie', 'female'),
#  ('Rhodie', 'female'),
#  ('Shem', 'male'),
#  ('Erena', 'female'),
#  ('Guinna', 'female'),
#  ('Karleen', 'female'),
#  ('Joey', 'female'),
#  ('Brietta', 'female'),
#  ('Stavros', 'male'),
#  ('Roseann', 'female'),
#  ('Corrie', 'female'),
#  ('Jaquenette', 'female'),
#  ('Clarabelle', 'female'),
#  ('Jenette', 'female'),
#  ('Jerrold', 'male'),
#  ('Henrie', 'male'),
#  ('Evangelia', 'female'),
#  ('Tuck', 'male'),
#  ('Ofella', 'female'),
#  ('Heidie', 'female'),
#  ('Paulo', 'male'),
#  ('Verine', 'female'),
#  ('Hope', 'female'),
#  ('Siouxie', 'female'),
#  ('Minnie', 'female'),
#  ('Scarlet', 'female'),
#  ('Ianthe', 'female'),
#  ('Eleanora', 'female'),
#  ('Avraham', 'male'),
#  ('Vitia', 'female'),
#  ('Nelle', 'female'),
#  ('Valry', 'female'),
#  ('Zed', 'male'),
#  ('Lindsy', 'female'),
#  ('Britani', 'female'),
#  ('Minerva', 'female'),
#  ('Case', 'male'),
#  ('Philipa', 'female'),
#  ('Sancho', 'male'),
#  ('Elvira', 'female'),
#  ('Adeline', 'female'),
#  ('Elmer', 'male'),
#  ('Glenda', 'female'),
#  ('Gusty', 'female'),
#  ('Knox', 'male'),
#  ('Chelsea', 'female'),
#  ('Dodi', 'female'),
#  ('Adella', 'female'),
#  ('Nady', 'female'),
#  ('Tanya', 'female'),
#  ('Florette', 'female'),
#  ('Meryl', 'male'),
#  ('Vinny', 'female'),
#  ('Ximenes', 'male'),
#  ('Roslyn', 'female'),
#  ('Dougie', 'male'),
#  ('Kelsy', 'female'),
#  ('Amery', 'male'),
#  ('Bess', 'female'),
#  ('Standford', 'male'),
#  ('Trude', 'female'),
#  ('Larina', 'female'),
#  ('Gwendolin', 'female'),
#  ('Kati', 'female'),
#  ('Les', 'male'),
#  ('Flem', 'male'),
#  ('Bernette', 'female'),
#  ('Harley', 'female'),
#  ('Walt', 'male'),
#  ('Durward', 'male'),
#  ('Cathryn', 'female'),
#  ('Jaleh', 'female'),
#  ('Corrinne', 'female'),
#  ('Mellie', 'female'),
#  ('Austen', 'male'),
#  ('Becky', 'female'),
#  ('Nichol', 'female'),
#  ('Dulsea', 'female'),
#  ('Ester', 'female'),
#  ('Bartholemy', 'male'),
#  ('Guillaume', 'male'),
#  ('Vickie', 'female'),
#  ('Lindy', 'male'),
#  ('Katharine', 'female'),
#  ('Graehme', 'male'),
#  ('Jessalin', 'female'),
#  ('Izabel', 'female'),
#  ('Leoine', 'female'),
#  ('Mireielle', 'female'),
#  ('Jonas', 'male'),
#  ('Yolane', 'female'),
#  ('Meredith', 'male'),
#  ('Beatrice', 'female'),
#  ('Alejandro', 'male'),
#  ('Ollie', 'female'),
#  ('Leela', 'female'),
#  ('Henry', 'male'),
#  ('Trenna', 'female'),
#  ('Sibbie', 'female'),
#  ('Fredra', 'female'),
#  ('Ambrosius', 'male'),
#  ('Gwyn', 'female'),
#  ('Goldarina', 'female'),
#  ('Lesly', 'female'),
#  ('Celeste', 'female'),
#  ('Andrus', 'male'),
#  ('Donnie', 'female'),
#  ('Johnnie', 'male'),
#  ('Kimberlyn', 'female'),
#  ('Milton', 'male'),
#  ('Bridgett', 'female'),
#  ('Christophe', 'male'),
#  ('Dedie', 'female'),
#  ('Brina', 'female'),
#  ('Clarinda', 'female'),
#  ('Kevin', 'male'),
#  ('Roanne', 'female'),
#  ('Shauna', 'female'),
#  ('Vachel', 'male'),
#  ('Mauricio', 'male'),
#  ('Dieter', 'male'),
#  ('Bernie', 'female'),
#  ('Tabbie', 'female'),
#  ('Aileen', 'female'),
#  ('Zalman', 'male'),
#  ('Ana', 'female'),
#  ('Corabella', 'female'),
#  ('Susann', 'female'),
#  ('Andromache', 'female'),
#  ('Ambrose', 'male'),
#  ('Nerta', 'female'),
#  ('Jonny', 'male'),
#  ('Nancy', 'female'),
#  ('Fowler', 'male'),
#  ('Baillie', 'male'),
#  ('Xerxes', 'male'),
#  ('Dominique', 'female'),
#  ('Ania', 'female'),
#  ('Anatol', 'male'),
#  ('Kasey', 'female'),
#  ('Burton', 'male'),
#  ('Rena', 'female'),
#  ('Dora', 'female'),
#  ('Philippine', 'female'),
#  ('Elyssa', 'female'),
#  ('Cassey', 'female'),
#  ('Roobbie', 'female'),
#  ('Karel', 'male'),
#  ('Gypsy', 'female'),
#  ('Basil', 'male'),
#  ('Shea', 'female'),
#  ('Ronny', 'male'),
#  ('Corky', 'male'),
#  ('Devon', 'male'),
#  ('Ave', 'male'),
#  ('Stephana', 'female'),
#  ('Sara-Ann', 'female'),
#  ('Vanna', 'female'),
#  ('Russell', 'male'),
#  ('Daniele', 'female'),
#  ('Pietro', 'male'),
#  ('Justina', 'female'),
#  ('Wallache', 'male'),
#  ('Endora', 'female'),
#  ('Kimbra', 'female'),
#  ('Eda', 'female'),
#  ('Price', 'male'),
#  ('Sherry', 'female'),
#  ('Richardo', 'male'),
#  ('Alex', 'male'),
#  ('Estrellita', 'female'),
#  ('Godfry', 'male'),
#  ('Janot', 'female'),
#  ('Delphine', 'female'),
#  ('Reynard', 'male'),
#  ('Solomon', 'male'),
#  ('Del', 'male'),
#  ('Josey', 'female'),
#  ('Jerry', 'female'),
#  ('Sydel', 'female'),
#  ('Dani', 'male'),
#  ('Trip', 'male'),
#  ('Cristen', 'female'),
#  ('Corene', 'female'),
#  ('Lesli', 'female'),
#  ('Nicky', 'female'),
#  ('Anica', 'female'),
#  ('Timmie', 'female'),
#  ('Corabel', 'female'),
#  ('Rodge', 'male'),
#  ('Tommi', 'female'),
#  ('Vivianne', 'female'),
#  ('Moore', 'male'),
#  ('Augustine', 'female'),
#  ('Alexine', 'female'),
#  ('Adelice', 'female'),
#  ('Naoma', 'female'),
#  ('Marian', 'female'),
#  ('Barbette', 'female'),
#  ('Bonita', 'female'),
#  ('Byram', 'male'),
#  ('Hill', 'male'),
#  ('Keene', 'male'),
#  ('Felipa', 'female'),
#  ('Marthe', 'female'),
#  ('Dario', 'male'),
#  ('Patrica', 'female'),
#  ('Jobi', 'female'),
#  ('Connie', 'female'),
#  ('Ace', 'male'),
#  ('Vanny', 'female'),
#  ('Cinda', 'female'),
#  ('Cicely', 'female'),
#  ('Randy', 'male'),
#  ('Jilli', 'female'),
#  ('Modesta', 'female'),
#  ('Barbabas', 'male'),
#  ('Dwaine', 'male'),
#  ('Robin', 'female'),
#  ('Giana', 'female'),
#  ('Caleb', 'male'),
#  ('Zechariah', 'male'),
#  ('Milena', 'female'),
#  ('Glen', 'male'),
#  ('Hildegarde', 'female'),
#  ('Zola', 'female'),
#  ('Casie', 'female'),
#  ('Mike', 'male'),
#  ('Emmanuel', 'male'),
#  ('Maurise', 'male'),
#  ('Sully', 'male'),
#  ('Camella', 'female'),
#  ('Margo', 'female'),
#  ('Nevile', 'male'),
#  ('Irvin', 'male'),
#  ('Jeremias', 'male'),
#  ('Roby', 'female'),
#  ('Dierdre', 'female'),
#  ('Rheta', 'female'),
#  ('Jackqueline', 'female'),
#  ('Lianne', 'female'),
#  ('Roderick', 'male'),
#  ('Nara', 'female'),
#  ('Jeraldine', 'female'),
#  ('Ronnie', 'male'),
#  ('Waine', 'male'),
#  ('Mora', 'female'),
#  ('Maurits', 'male'),
#  ('Rubina', 'female'),
#  ('Samuella', 'female'),
#  ('Bambie', 'female'),
#  ('Babs', 'female'),
#  ('Bobby', 'male'),
#  ('Julieta', 'female'),
#  ('Witold', 'male'),
#  ('Andre', 'male'),
#  ('Lanette', 'female'),
#  ('Janis', 'female'),
#  ('Agamemnon', 'male'),
#  ('Jennee', 'female'),
#  ('Celestyn', 'female'),
#  ('Sissie', 'female'),
#  ('Benji', 'male'),
#  ('Charmaine', 'female'),
#  ('Marinna', 'female'),
#  ('Marga', 'female'),
#  ('Tuckie', 'male'),
#  ('Reena', 'female'),
#  ('Constancy', 'female'),
#  ('Francoise', 'female'),
#  ('Carolyn', 'female'),
#  ('Carena', 'female'),
#  ('Mureil', 'female'),
#  ('Barri', 'male'),
#  ('Karilynn', 'female'),
#  ('Armand', 'male'),
#  ('Blondy', 'female'),
#  ('Zack', 'male'),
#  ('Lora', 'female'),
#  ('Madalyn', 'female'),
#  ('Rice', 'male'),
#  ('Archon', 'male'),
#  ('Tillie', 'female'),
#  ('Marcos', 'male'),
#  ('Beverly', 'female'),
#  ('Tonia', 'female'),
#  ('Verney', 'male'),
#  ('Gipsy', 'female'),
#  ('Elvera', 'female'),
#  ('Tobye', 'female'),
#  ('Stephenie', 'female'),
#  ('Arlyne', 'female'),
#  ('Thane', 'male'),
#  ('Kalli', 'female'),
#  ('April', 'female'),
#  ('Fanchette', 'female'),
#  ('Cybil', 'female'),
#  ('Istvan', 'male'),
#  ('Torin', 'male'),
#  ('Judah', 'male'),
#  ('Gilles', 'male'),
#  ('Harrie', 'female'),
#  ('Yoshiko', 'female'),
#  ('Tarrance', 'male'),
#  ('Judas', 'male'),
#  ('France', 'female'),
#  ('Querida', 'female'),
#  ('Kassie', 'female'),
#  ('Tiffy', 'female'),
#  ('Ariana', 'female'),
#  ('Jacinta', 'female'),
#  ('Arlena', 'female'),
#  ('Tonya', 'female'),
#  ('Allie', 'male'),
#  ('Wynn', 'male'),
#  ('Ernst', 'male'),
#  ('Colleen', 'female'),
#  ('Tildie', 'female'),
#  ('Demetri', 'male'),
#  ('Cherie', 'female'),
#  ('Portia', 'female'),
#  ('Stormy', 'female'),
#  ('Lind', 'female'),
#  ('Rosene', 'female'),
#  ('Isador', 'male'),
#  ('Margie', 'female'),
#  ('Bria', 'female'),
#  ('Sybil', 'female'),
#  ('Leonie', 'female'),
#  ('Maure', 'female'),
#  ('Percival', 'male'),
#  ('Nichole', 'male'),
#  ('Barbi', 'female'),
#  ('Jenifer', 'female'),
#  ('Ambros', 'male'),
#  ('Suzi', 'female'),
#  ('Rebe', 'female'),
#  ('Rayshell', 'female'),
#  ('Brenn', 'female'),
#  ('Casia', 'female'),
#  ('Marion', 'female'),
#  ('Shellie', 'female'),
#  ('Terina', 'female'),
#  ('Agretha', 'female'),
#  ('Ettie', 'female'),
#  ('Storey', 'female'),
#  ('Ariella', 'female'),
#  ('Teodoor', 'male'),
#  ('Shana', 'female'),
#  ('Harland', 'male'),
#  ('Buck', 'male'),
#  ('Georgianna', 'female'),
#  ('Yvette', 'female'),
#  ('Candi', 'female'),
#  ('Tamara', 'female'),
#  ('Carleen', 'female'),
#  ('Claudius', 'male'),
#  ('Addis', 'female'),
#  ('Odell', 'male'),
#  ('Fonz', 'male'),
#  ('Barbey', 'female'),
#  ('Christiano', 'male'),
#  ('Doug', 'male'),
#  ('Levin', 'male'),
#  ('Bettye', 'female'),
#  ('Jimmy', 'male'),
#  ('Graeme', 'male'),
#  ('Hew', 'male'),
#  ('Derrol', 'male'),
#  ('Marsiella', 'female'),
#  ('Germana', 'female'),
#  ('Jade', 'female'),
#  ('Saree', 'female'),
#  ('Effie', 'female'),
#  ('Genevra', 'female'),
#  ('Elonore', 'female'),
#  ('Giraldo', 'male'),
#  ('Nicoline', 'female'),
#  ('Winnie', 'female'),
#  ('Kalle', 'male'),
#  ('Merline', 'female'),
#  ('Baxter', 'male'),
#  ('Mitch', 'male'),
#  ('Buster', 'male'),
#  ('Nydia', 'female'),
#  ('Chevalier', 'male'),
#  ('Curt', 'male'),
#  ('Kriste', 'female'),
#  ('Wait', 'male'),
#  ('Joella', 'female'),
#  ('Sonnnie', 'female'),
#  ('Lidia', 'female'),
#  ('Petronille', 'female'),
#  ('Lotta', 'female'),
#  ('Aldric', 'male'),
#  ('Ardene', 'female'),
#  ('Rosalind', 'female'),
#  ('Hamil', 'male'),
#  ('Dallas', 'female'),
#  ('Stefanie', 'female'),
#  ('Kathrine', 'female'),
#  ('Maddy', 'male'),
#  ('Kiri', 'female'),
#  ('Skippie', 'male'),
#  ('Maddy', 'female'),
#  ('Moina', 'female'),
#  ('Micky', 'female'),
#  ('Gillan', 'female'),
#  ('Martie', 'female'),
#  ('Dorothee', 'female'),
#  ('Appolonia', 'female'),
#  ('Dana', 'male'),
#  ('Baron', 'male'),
#  ('Orbadiah', 'male'),
#  ('Cob', 'male'),
#  ('Allianora', 'female'),
#  ('Tobey', 'female'),
#  ('Fons', 'male'),
#  ('Marcie', 'female'),
#  ('Parwane', 'female'),
#  ('Anatoly', 'male'),
#  ('Doralynn', 'female'),
#  ('Olia', 'female'),
#  ('Dante', 'male'),
#  ('Glynda', 'female'),
#  ('Odele', 'female'),
#  ('Lettie', 'female'),
#  ('Winny', 'female'),
#  ('Arnold', 'male'),
#  ('Roxi', 'female'),
#  ('Murray', 'male'),
#  ('Fae', 'female'),
#  ('Godfree', 'male'),
#  ('Nils', 'male'),
#  ('Alford', 'male'),
#  ('Andreas', 'male'),
#  ('Lucio', 'male'),
#  ('Lucienne', 'female'),
#  ('Beverlie', 'female'),
#  ('Cory', 'female'),
#  ('Stella', 'female'),
#  ('Maureene', 'female'),
#  ('Elita', 'female'),
#  ('Jean-Lou', 'male'),
#  ('Philis', 'female'),
#  ('Mayer', 'male'),
#  ('Courtney', 'female'),
#  ('Clair', 'female'),
#  ('Marquita', 'female'),
#  ('Merrielle', 'female'),
#  ('Dirk', 'male'),
#  ('Hilliard', 'male'),
#  ('Xylina', 'female'),
#  ('Love', 'female'),
#  ('Federica', 'female'),
#  ('Harriett', 'female'),
#  ('Oreste', 'female'),
#  ('Cornelius', 'male'),
#  ('Rhea', 'female'),
#  ('Row', 'female'),
#  ('Trixy', 'female'),
#  ('Sergio', 'male'),
#  ('Neysa', 'female'),
#  ('Clarence', 'male'),
#  ('Bryn', 'male'),
#  ('Goddart', 'male'),
#  ('Ritchie', 'male'),
#  ('Layla', 'female'),
#  ('Rycca', 'female'),
#  ('Willi', 'male'),
#  ('Glennie', 'female'),
#  ('Melony', 'female'),
#  ('Sybilla', 'female'),
#  ('Vivyan', 'female'),
#  ('Marlin', 'male'),
#  ('Weider', 'male'),
#  ('Jammie', 'female'),
#  ('Mathias', 'male'),
#  ('Arlo', 'male'),
#  ('Sylvia', 'female'),
#  ('Jocelyne', 'female'),
#  ('Nester', 'male'),
#  ('Cherey', 'female'),
#  ('Hildegaard', 'female'),
#  ('Granville', 'male'),
#  ('Marsha', 'female'),
#  ('Virgie', 'female'),
#  ('Emery', 'male'),
#  ('Pammy', 'female'),
#  ('Hervey', 'male'),
#  ('Erhard', 'male'),
#  ('Talbot', 'male'),
#  ('Jocelyn', 'female'),
#  ('Midge', 'female'),
#  ('Samuele', 'male'),
#  ('Bianca', 'female'),
#  ('Theresita', 'female'),
#  ('Saunder', 'male'),
#  ('Rosemaria', 'female'),
#  ('Dasi', 'female'),
#  ('Patin', 'male'),
#  ('Stearn', 'male'),
#  ('Liorah', 'female'),
#  ('Chen', 'male'),
#  ('Celle', 'female'),
#  ('Joy', 'female'),
#  ('Tybie', 'female'),
#  ('Doreen', 'female'),
#  ('Freddy', 'female'),
#  ('Jeane', 'female'),
#  ('Gavin', 'male'),
#  ('Wyatt', 'male'),
#  ('Petr', 'male'),
#  ('Cassandra', 'female'),
#  ('Ignaz', 'male'),
#  ('Olimpia', 'female'),
#  ...]

# %%
names
# Out:
# [('Tine', 'female'),
#  ('Tanya', 'female'),
#  ('Gomer', 'male'),
#  ('Jillana', 'female'),
#  ('Christ', 'male'),
#  ('Julianne', 'female'),
#  ('Dory', 'male'),
#  ('Jude', 'male'),
#  ('Hollie', 'female'),
#  ('Claudio', 'male'),
#  ('Christal', 'female'),
#  ('Gabriella', 'female'),
#  ('Fatima', 'female'),
#  ('Hersh', 'male'),
#  ('Minna', 'female'),
#  ('Nate', 'male'),
#  ('Beowulf', 'male'),
#  ('Aloysius', 'male'),
#  ('Nisa', 'female'),
#  ('Lee', 'male'),
#  ('Lorettalorna', 'female'),
#  ('Danya', 'female'),
#  ('Petr', 'male'),
#  ('Gilbertina', 'female'),
#  ('Dode', 'female'),
#  ('Sammy', 'male'),
#  ('Carlena', 'female'),
#  ('Jo', 'female'),
#  ('Josh', 'male'),
#  ('Selena', 'female'),
#  ('Chane', 'male'),
#  ('Anallese', 'female'),
#  ('Dix', 'female'),
#  ('Isidore', 'male'),
#  ('Chalmers', 'male'),
#  ('Chryste', 'female'),
#  ('Neale', 'male'),
#  ('Isidora', 'female'),
#  ('Theodoric', 'male'),
#  ('Radcliffe', 'male'),
#  ('Sada', 'female'),
#  ('Audra', 'female'),
#  ('Austin', 'male'),
#  ('Chaddy', 'male'),
#  ('Regina', 'female'),
#  ('Latia', 'female'),
#  ('Alanah', 'female'),
#  ('Lizbeth', 'female'),
#  ('Archie', 'male'),
#  ('Andra', 'female'),
#  ('Tucky', 'male'),
#  ('Gwendolen', 'female'),
#  ('Chancey', 'male'),
#  ('Othello', 'male'),
#  ('Mel', 'female'),
#  ('Chloris', 'female'),
#  ('Sybil', 'female'),
#  ('Legra', 'female'),
#  ('Deloria', 'female'),
#  ('Derek', 'male'),
#  ('Annmarie', 'female'),
#  ('Dotty', 'female'),
#  ('Dorella', 'female'),
#  ('Nataline', 'female'),
#  ('Lyda', 'female'),
#  ('Liorah', 'female'),
#  ('Margarete', 'female'),
#  ('Mercy', 'female'),
#  ('Candra', 'female'),
#  ('Martie', 'female'),
#  ('Donetta', 'female'),
#  ('Seth', 'male'),
#  ('Merla', 'female'),
#  ('Christie', 'male'),
#  ('Bartie', 'male'),
#  ('Dunc', 'male'),
#  ('Jeannette', 'female'),
#  ('Nichol', 'female'),
#  ('Virgie', 'female'),
#  ('Welbie', 'male'),
#  ('Julianna', 'female'),
#  ('Nerissa', 'female'),
#  ('Melicent', 'female'),
#  ('Joya', 'female'),
#  ('Shirl', 'female'),
#  ('Lynnett', 'female'),
#  ('Kristos', 'male'),
#  ('Darda', 'female'),
#  ('Corny', 'female'),
#  ('Hedvig', 'female'),
#  ('Devon', 'male'),
#  ('Alica', 'female'),
#  ('Bel', 'female'),
#  ('Lottie', 'female'),
#  ('Rasia', 'female'),
#  ('Ashby', 'male'),
#  ('Phillipp', 'male'),
#  ('Sergeant', 'male'),
#  ('Christos', 'male'),
#  ('Idaline', 'female'),
#  ('Lillian', 'female'),
#  ('Lisbeth', 'female'),
#  ('Selie', 'female'),
#  ('Joana', 'female'),
#  ('Ransom', 'male'),
#  ('Knox', 'male'),
#  ('Belvia', 'female'),
#  ('Alley', 'male'),
#  ('Carlie', 'male'),
#  ('Dorry', 'female'),
#  ('Zarla', 'female'),
#  ('Marietta', 'female'),
#  ('Izabel', 'female'),
#  ('Obadias', 'male'),
#  ('Wylma', 'female'),
#  ('Thorstein', 'male'),
#  ('Michelina', 'female'),
#  ('Agnella', 'female'),
#  ('Shandra', 'female'),
#  ('Gere', 'male'),
#  ('Flipper', 'male'),
#  ('Jordan', 'female'),
#  ('Dacy', 'female'),
#  ('Luella', 'female'),
#  ('Mallissa', 'female'),
#  ('Vilhelmina', 'female'),
#  ('Tann', 'male'),
#  ('Sayre', 'female'),
#  ('Robin', 'female'),
#  ('Erin', 'female'),
#  ('Arlo', 'male'),
#  ('Truman', 'male'),
#  ('Elliott', 'male'),
#  ('Maryl', 'female'),
#  ('Debra', 'female'),
#  ('Ashish', 'male'),
#  ('Calypso', 'female'),
#  ('Lynnette', 'female'),
#  ('Catharine', 'female'),
#  ('Carmen', 'female'),
#  ('Marchelle', 'female'),
#  ('Chrissy', 'female'),
#  ('Vito', 'male'),
#  ('Janenna', 'female'),
#  ('Livia', 'female'),
#  ('Adeline', 'female'),
#  ('Dugan', 'male'),
#  ('Sibella', 'female'),
#  ('Ebba', 'female'),
#  ('Allen', 'male'),
#  ('Kally', 'female'),
#  ('Devonne', 'female'),
#  ('Mick', 'male'),
#  ('Chrysler', 'female'),
#  ('Elnar', 'male'),
#  ('Matt', 'male'),
#  ('Delcine', 'female'),
#  ('Delly', 'female'),
#  ('Gian', 'male'),
#  ('Bjorn', 'male'),
#  ('Eloisa', 'female'),
#  ('Uri', 'male'),
#  ('Jill', 'female'),
#  ('Shana', 'female'),
#  ('Ulick', 'male'),
#  ('Clifford', 'male'),
#  ('Averyl', 'female'),
#  ('Cobb', 'male'),
#  ('Marchall', 'male'),
#  ('Rae', 'female'),
#  ('Mimi', 'female'),
#  ('Philippe', 'female'),
#  ('Carmina', 'female'),
#  ('Cliff', 'male'),
#  ('Ruthe', 'female'),
#  ('Mildred', 'female'),
#  ('Clio', 'female'),
#  ('Shea', 'female'),
#  ('Emlynne', 'female'),
#  ('Terrye', 'female'),
#  ('Meriel', 'female'),
#  ('Belia', 'female'),
#  ('Keri', 'female'),
#  ('Andreana', 'female'),
#  ('Hetty', 'female'),
#  ('Kaye', 'female'),
#  ('Ally', 'female'),
#  ('Kingsley', 'male'),
#  ('Thedrick', 'male'),
#  ('Zacherie', 'male'),
#  ('Corinna', 'female'),
#  ('Karmen', 'female'),
#  ('Raymundo', 'male'),
#  ('Gabriele', 'male'),
#  ('Farica', 'female'),
#  ('Junina', 'female'),
#  ('Lucilia', 'female'),
#  ('Janine', 'female'),
#  ('Gredel', 'female'),
#  ('Torie', 'female'),
#  ('Garrett', 'male'),
#  ('Dian', 'female'),
#  ('Donella', 'female'),
#  ('Alex', 'male'),
#  ('Reinhold', 'male'),
#  ('Christy', 'male'),
#  ('Rivalee', 'female'),
#  ('Mitchel', 'male'),
#  ('Ethelda', 'female'),
#  ('Sargent', 'male'),
#  ('Jeffrey', 'male'),
#  ('Renelle', 'female'),
#  ('Philomena', 'female'),
#  ('Avie', 'female'),
#  ('Berna', 'female'),
#  ('Jessi', 'female'),
#  ('Renie', 'female'),
#  ('Vaughn', 'male'),
#  ('Loella', 'female'),
#  ('Ulrika', 'female'),
#  ('Arlen', 'female'),
#  ('Jenny', 'female'),
#  ('Thurston', 'male'),
#  ('Dolora', 'female'),
#  ('Pen', 'male'),
#  ('Leanor', 'female'),
#  ('Demetra', 'female'),
#  ('Aurie', 'female'),
#  ('Alphonso', 'male'),
#  ('Catherin', 'female'),
#  ('Yolande', 'female'),
#  ('Roselin', 'female'),
#  ('Francine', 'female'),
#  ('Kevin', 'male'),
#  ('Noami', 'female'),
#  ('Lydie', 'female'),
#  ('Malcolm', 'male'),
#  ('Eric', 'male'),
#  ('Joleen', 'female'),
#  ('Yelena', 'female'),
#  ('Kalinda', 'female'),
#  ('Cesya', 'female'),
#  ('Norbert', 'male'),
#  ('Nariko', 'female'),
#  ('Luciano', 'male'),
#  ('Ambros', 'male'),
#  ('Seline', 'female'),
#  ('Gerrard', 'male'),
#  ('Minnie', 'female'),
#  ('Margo', 'female'),
#  ('Christian', 'male'),
#  ('Jaime', 'female'),
#  ('Shelagh', 'female'),
#  ('Marie-Jeanne', 'female'),
#  ('Cameo', 'female'),
#  ('Fergus', 'male'),
#  ('Joyce', 'female'),
#  ('Libbi', 'female'),
#  ('Aloysia', 'female'),
#  ('Mireielle', 'female'),
#  ('Rosita', 'female'),
#  ('Cary', 'male'),
#  ('Rudolf', 'male'),
#  ('Shirline', 'female'),
#  ('Stanislaw', 'male'),
#  ('Tabbie', 'female'),
#  ('Les', 'male'),
#  ('Salvatore', 'male'),
#  ('Austin', 'female'),
#  ('Jerry', 'male'),
#  ('Jerrie', 'male'),
#  ('Gilberta', 'female'),
#  ('Cammi', 'female'),
#  ('Laurence', 'male'),
#  ('Chiarra', 'female'),
#  ('Constantina', 'female'),
#  ('Van', 'female'),
#  ('Jo', 'male'),
#  ('Reynard', 'male'),
#  ('Marian', 'female'),
#  ('Serge', 'male'),
#  ('Alton', 'male'),
#  ('Levi', 'male'),
#  ('Corky', 'male'),
#  ('Rufe', 'male'),
#  ('Ira', 'female'),
#  ('Andria', 'female'),
#  ('Wash', 'male'),
#  ('Lucien', 'male'),
#  ('Enid', 'female'),
#  ('Elyssa', 'female'),
#  ('Veronike', 'female'),
#  ('Cassey', 'female'),
#  ('Carolin', 'female'),
#  ('Dorisa', 'female'),
#  ('Moya', 'female'),
#  ('Germain', 'female'),
#  ('Hannis', 'female'),
#  ('Sheelah', 'female'),
#  ('Madeline', 'female'),
#  ('Flinn', 'male'),
#  ('Alvin', 'male'),
#  ('Huntlee', 'male'),
#  ('Mandy', 'female'),
#  ('Estel', 'female'),
#  ('Noam', 'male'),
#  ('Spenser', 'male'),
#  ('Twyla', 'female'),
#  ('Fitz', 'male'),
#  ('Fanya', 'female'),
#  ('Aleksandrs', 'male'),
#  ('Emogene', 'female'),
#  ('Gillie', 'female'),
#  ('Mart', 'male'),
#  ('Dorita', 'female'),
#  ('Elise', 'female'),
#  ('Aleen', 'female'),
#  ('Crissy', 'female'),
#  ('Cherida', 'female'),
#  ('Justin', 'male'),
#  ('Erinna', 'female'),
#  ('Shelli', 'female'),
#  ('Coralyn', 'female'),
#  ('Nanci', 'female'),
#  ('Jo-Anne', 'female'),
#  ('Sallyanne', 'female'),
#  ('Dania', 'female'),
#  ('Agnesse', 'female'),
#  ('Kylie', 'female'),
#  ('Thorpe', 'male'),
#  ('Tonia', 'female'),
#  ('Benito', 'male'),
#  ('Lucius', 'male'),
#  ('Diamond', 'female'),
#  ('Hiram', 'male'),
#  ('Jenine', 'female'),
#  ('Mustafa', 'male'),
#  ('Armando', 'male'),
#  ('Yardley', 'male'),
#  ('Kali', 'female'),
#  ('Tierney', 'female'),
#  ('Berenice', 'female'),
#  ('Laird', 'male'),
#  ('Georgeanna', 'female'),
#  ('Gui', 'female'),
#  ('Hall', 'male'),
#  ('Pauli', 'female'),
#  ('Stanford', 'male'),
#  ('Sandy', 'female'),
#  ('Randy', 'male'),
#  ('Carter', 'male'),
#  ('Tulley', 'male'),
#  ('Larry', 'male'),
#  ('Nolana', 'female'),
#  ('Jaquenette', 'female'),
#  ('Leora', 'female'),
#  ('Meier', 'male'),
#  ('Marika', 'female'),
#  ('Danielle', 'female'),
#  ('Jorey', 'female'),
#  ('Butler', 'male'),
#  ('Danie', 'male'),
#  ('Carly', 'female'),
#  ('Dottie', 'female'),
#  ('Margette', 'female'),
#  ('Willey', 'male'),
#  ('Whittaker', 'male'),
#  ('Sharron', 'female'),
#  ('Gena', 'female'),
#  ('Birdie', 'female'),
#  ('Robbin', 'female'),
#  ('Dolores', 'female'),
#  ('Orelee', 'female'),
#  ('Krista', 'female'),
#  ('Bamby', 'female'),
#  ('Prasun', 'male'),
#  ('Golda', 'female'),
#  ('Eilis', 'female'),
#  ('Ag', 'female'),
#  ('Alyda', 'female'),
#  ('Sharia', 'female'),
#  ('Mattheus', 'male'),
#  ('Linnie', 'female'),
#  ('Ernie', 'male'),
#  ('Robbie', 'male'),
#  ('Lisette', 'female'),
#  ('Lark', 'female'),
#  ('Morganne', 'female'),
#  ('Dorothy', 'female'),
#  ('Derron', 'male'),
#  ('Friedric', 'male'),
#  ('Sherilyn', 'female'),
#  ('Shawn', 'female'),
#  ('Nichols', 'male'),
#  ('Graham', 'male'),
#  ('Herrick', 'male'),
#  ('Nikki', 'female'),
#  ('Lynea', 'female'),
#  ('Darryl', 'male'),
#  ('Lisha', 'female'),
#  ('Hartwell', 'male'),
#  ('Inglebert', 'male'),
#  ('Wilmette', 'female'),
#  ('Raye', 'female'),
#  ('Eli', 'male'),
#  ('Reube', 'male'),
#  ('Joshua', 'male'),
#  ('Abby', 'male'),
#  ('Cyb', 'female'),
#  ('Aveline', 'female'),
#  ('Irwin', 'male'),
#  ('Benny', 'female'),
#  ('Ashleigh', 'female'),
#  ('Gregorio', 'male'),
#  ('Jasmina', 'female'),
#  ('La', 'female'),
#  ('Eulalie', 'female'),
#  ('Zaria', 'female'),
#  ('Ursola', 'female'),
#  ('Merv', 'male'),
#  ('Myrtie', 'female'),
#  ('Cherilyn', 'female'),
#  ('Fidel', 'male'),
#  ('Shaine', 'female'),
#  ('Stormy', 'female'),
#  ('Sharity', 'female'),
#  ('Babette', 'female'),
#  ('Diego', 'male'),
#  ('Lula', 'female'),
#  ('Leticia', 'female'),
#  ('Welsh', 'male'),
#  ('Beilul', 'female'),
#  ('Neel', 'male'),
#  ('Isabelle', 'female'),
#  ('Giffer', 'male'),
#  ('Hammad', 'male'),
#  ('Thornton', 'male'),
#  ('Melany', 'female'),
#  ('Sherline', 'female'),
#  ('Marsh', 'male'),
#  ('Nanine', 'female'),
#  ('Tobit', 'male'),
#  ('Dasya', 'female'),
#  ('Hanna', 'female'),
#  ('Howard', 'male'),
#  ('Rene', 'male'),
#  ('Lian', 'female'),
#  ('Ronald', 'male'),
#  ('Ree', 'female'),
#  ('Marcia', 'female'),
#  ('Aurora', 'female'),
#  ('Abagael', 'female'),
#  ('Yule', 'male'),
#  ('Zolly', 'male'),
#  ('Benjie', 'male'),
#  ('Marshall', 'male'),
#  ('Sherie', 'female'),
#  ('Stanleigh', 'male'),
#  ('Hugh', 'male'),
#  ('Gustave', 'male'),
#  ('Keriann', 'female'),
#  ('Tara', 'female'),
#  ('Chelsea', 'female'),
#  ('Jabez', 'male'),
#  ('Josee', 'female'),
#  ('Eleanore', 'female'),
#  ('Regen', 'male'),
#  ('Hershel', 'male'),
#  ('Elizabet', 'female'),
#  ('Kelwin', 'male'),
#  ('Yancy', 'male'),
#  ('Hadrian', 'male'),
#  ('Lowell', 'male'),
#  ('Vivienne', 'female'),
#  ('Merna', 'female'),
#  ('Janie', 'female'),
#  ('Hilda', 'female'),
#  ('Eduardo', 'male'),
#  ('Gil', 'male'),
#  ('Glennis', 'female'),
#  ('Edouard', 'male'),
#  ('Sting', 'male'),
#  ('Georgiana', 'female'),
#  ('Sheba', 'female'),
#  ('Montgomery', 'male'),
#  ('Franky', 'female'),
#  ('See', 'male'),
#  ('Phineas', 'male'),
#  ('Nickolas', 'male'),
#  ('Dona', 'female'),
#  ('Justis', 'male'),
#  ('Dunstan', 'male'),
#  ('Stu', 'male'),
#  ('Herbie', 'male'),
#  ('Mae', 'female'),
#  ('Sabina', 'female'),
#  ('Esmerelda', 'female'),
#  ('Gustie', 'female'),
#  ('Angela', 'female'),
#  ('Sharyl', 'female'),
#  ('Gale ', 'female'),
#  ('Talyah', 'female'),
#  ('Osgood', 'male'),
#  ('Barbette', 'female'),
#  ('Rica', 'female'),
#  ('Darwin', 'male'),
#  ('Connie', 'female'),
#  ('Alysa', 'female'),
#  ('Zed', 'male'),
#  ('Jobie', 'female'),
#  ('Lucky', 'female'),
#  ('Lane', 'male'),
#  ('Ginger', 'female'),
#  ('Antonina', 'female'),
#  ('Ephrayim', 'male'),
#  ('Beret', 'female'),
#  ('Nerti', 'female'),
#  ('Poul', 'male'),
#  ('Rolf', 'male'),
#  ('Rodrigo', 'male'),
#  ('Kikelia', 'female'),
#  ('Alonzo', 'male'),
#  ('Rosene', 'female'),
#  ('Letty', 'female'),
#  ('Jodee', 'female'),
#  ('Hermina', 'female'),
#  ('Dieter', 'male'),
#  ('Fay', 'female'),
#  ('Brandise', 'female'),
#  ('Sayre', 'male'),
#  ('Jocelin', 'female'),
#  ('Shannon', 'female'),
#  ('Sarge', 'male'),
#  ('Spiro', 'male'),
#  ('Katusha', 'female'),
#  ('Rich', 'male'),
#  ('Wyatan', 'male'),
#  ('Dale', 'male'),
#  ('Margareta', 'female'),
#  ('Brina', 'female'),
#  ('Alena', 'female'),
#  ('Monah', 'female'),
#  ('Pierson', 'male'),
#  ('Rabi', 'male'),
#  ('Calley', 'female'),
#  ('Elene', 'female'),
#  ('Stephani', 'female'),
#  ('Drea', 'female'),
#  ('Sax', 'male'),
#  ('Ehud', 'male'),
#  ('Moina', 'female'),
#  ('Morry', 'male'),
#  ('Fernandina', 'female'),
#  ('Vonny', 'female'),
#  ('Thaine', 'male'),
#  ('Jandy', 'female'),
#  ('Wyn', 'male'),
#  ('Stearne', 'male'),
#  ('Goldie', 'female'),
#  ('Marnia', 'female'),
#  ('Leonore', 'female'),
#  ('Timmy', 'female'),
#  ('Robinia', 'female'),
#  ('Xylina', 'female'),
#  ('Caitrin', 'female'),
#  ('Lyndell', 'female'),
#  ('Waiter', 'male'),
#  ('Pearla', 'female'),
#  ('Donni', 'female'),
#  ('Gretchen', 'male'),
#  ('Leo', 'male'),
#  ('Kellie', 'female'),
#  ('Keslie', 'female'),
#  ('Jania', 'female'),
#  ('Nadia', 'female'),
#  ('Hiro', 'male'),
#  ('Hercule', 'male'),
#  ('Dori', 'female'),
#  ('Ina', 'female'),
#  ('Barbaraanne', 'female'),
#  ('Aprilette', 'female'),
#  ('Rudolph', 'male'),
#  ('Ajay', 'male'),
#  ('Humbert', 'male'),
#  ('Nat', 'male'),
#  ('Karie', 'female'),
#  ('Robyn', 'female'),
#  ('Corabelle', 'female'),
#  ('Alida', 'female'),
#  ('Celesta', 'female'),
#  ('Amalle', 'female'),
#  ('Abbey', 'female'),
#  ('Preston', 'male'),
#  ('Hilary', 'female'),
#  ('Tynan', 'male'),
#  ('Alonso', 'male'),
#  ('Roderich', 'male'),
#  ('Gregory', 'male'),
#  ('Praneetf', 'male'),
#  ('Allyce', 'female'),
#  ('Rogers', 'male'),
#  ('Gonzalo', 'male'),
#  ('Laurella', 'female'),
#  ('Dixie', 'female'),
#  ('Crystie', 'female'),
#  ('Claretta', 'female'),
#  ('Neysa', 'female'),
#  ('Jaclin', 'female'),
#  ('Leonanie', 'female'),
#  ('Deana', 'female'),
#  ('Benedicta', 'female'),
#  ('Rozelle', 'female'),
#  ('Leyla', 'female'),
#  ('Alberto', 'male'),
#  ('Giraldo', 'male'),
#  ('Ariel', 'male'),
#  ('Heywood', 'male'),
#  ('Carey', 'male'),
#  ('Anthea', 'female'),
#  ('Jewel', 'female'),
#  ('Hortensia', 'female'),
#  ('Minerva', 'female'),
#  ('Meghann', 'female'),
#  ('Guillemette', 'female'),
#  ('Lex', 'male'),
#  ('Amabel', 'female'),
#  ('Missy', 'female'),
#  ('Marina', 'female'),
#  ('Towny', 'male'),
#  ('Easton', 'male'),
#  ('Lemmy', 'male'),
#  ('Caterina', 'female'),
#  ('Casper', 'male'),
#  ('Benita', 'female'),
#  ('Theresa', 'female'),
#  ('Selia', 'female'),
#  ('Alina', 'female'),
#  ('Annice', 'female'),
#  ('Janetta', 'female'),
#  ('Bayard', 'male'),
#  ('Austina', 'female'),
#  ('Marlyn', 'female'),
#  ('Krystalle', 'female'),
#  ('Danna', 'female'),
#  ('Constancia', 'female'),
#  ('Fremont', 'male'),
#  ('Vicki', 'female'),
#  ('Renato', 'male'),
#  ('Cherilynn', 'female'),
#  ('Jolyn', 'female'),
#  ('Kate', 'female'),
#  ('Glyn', 'female'),
#  ('Riane', 'female'),
#  ('Mora', 'female'),
#  ('Nonah', 'female'),
#  ('Gerti', 'female'),
#  ('Emera', 'female'),
#  ('Nessy', 'female'),
#  ('Berkie', 'male'),
#  ('Chris', 'male'),
#  ('Hazel', 'female'),
#  ('Bartolemo', 'male'),
#  ('Ivory', 'female'),
#  ('Stevy', 'male'),
#  ('Nickey', 'male'),
#  ('Bert', 'female'),
#  ('Heida', 'female'),
#  ('Cristionna', 'female'),
#  ('Waly', 'female'),
#  ('Maren', 'female'),
#  ('Ardath', 'female'),
#  ('Jillian', 'female'),
#  ('Kellia', 'female'),
#  ('Aleda', 'female'),
#  ('Juditha', 'female'),
#  ('Leela', 'female'),
#  ('Lucio', 'male'),
#  ('Lanny', 'female'),
#  ('Ramsay', 'male'),
#  ('Genny', 'female'),
#  ('Lothar', 'male'),
#  ('Karina', 'female'),
#  ('Kacie', 'female'),
#  ('Raimund', 'male'),
#  ('Daryl', 'female'),
#  ('Katrine', 'female'),
#  ('Harriot', 'female'),
#  ('Mariejeanne', 'female'),
#  ('Kori', 'female'),
#  ('Nanni', 'female'),
#  ('Almira', 'female'),
#  ('Aggie', 'female'),
#  ('Louie', 'male'),
#  ('Cybil', 'female'),
#  ('Alyson', 'female'),
#  ('Sparky', 'male'),
#  ('Wilek', 'male'),
#  ('Desaree', 'female'),
#  ('Peter', 'male'),
#  ('Major', 'male'),
#  ('Skipp', 'male'),
#  ('Glenda', 'female'),
#  ('Carlos', 'male'),
#  ('Prue', 'female'),
#  ('Kizzie', 'female'),
#  ('Karlotta', 'female'),
#  ('David', 'male'),
#  ('Mathilda', 'female'),
#  ('Anna-Diane', 'female'),
#  ('Marti', 'female'),
#  ('Sauncho', 'male'),
#  ('Miguela', 'female'),
#  ('Katharyn', 'female'),
#  ('Joshuah', 'male'),
#  ('Fawnia', 'female'),
#  ('Lilia', 'female'),
#  ('Jolene', 'female'),
#  ('Gladis', 'female'),
#  ('Thatch', 'male'),
#  ('Tait', 'male'),
#  ('Hewett', 'male'),
#  ('Lynelle', 'female'),
#  ('Matilda', 'female'),
#  ('Breena', 'female'),
#  ('Merilee', 'female'),
#  ('Wendel', 'male'),
#  ('Maxi', 'female'),
#  ('Winona', 'female'),
#  ('Petey', 'male'),
#  ('Jamey', 'male'),
#  ('Lawton', 'male'),
#  ('Inigo', 'male'),
#  ('Danny', 'male'),
#  ('Saba', 'female'),
#  ('Camala', 'female'),
#  ('Wake', 'male'),
#  ('Sander', 'male'),
#  ('Vasilis', 'male'),
#  ('Hillel', 'male'),
#  ('Glynis', 'female'),
#  ('Gilligan', 'female'),
#  ('Chrissa', 'female'),
#  ('Harriott', 'female'),
#  ('Cassandra', 'female'),
#  ('Natalia', 'female'),
#  ('Tally', 'female'),
#  ('Wayland', 'male'),
#  ('Abbot', 'male'),
#  ('Alvera', 'female'),
#  ('Kaila', 'female'),
#  ('Donovan', 'male'),
#  ('Carola', 'female'),
#  ('Gertrud', 'female'),
#  ('Collins', 'male'),
#  ('Adelice', 'female'),
#  ('Sal', 'male'),
#  ('Theda', 'female'),
#  ('Floris', 'female'),
#  ('Delcina', 'female'),
#  ('Stephannie', 'female'),
#  ('Margalit', 'female'),
#  ('Odie', 'male'),
#  ('Fiorenze', 'female'),
#  ('Batholomew', 'male'),
#  ('Noreen', 'female'),
#  ('Linea', 'female'),
#  ('Lavinia', 'female'),
#  ('Laureen', 'female'),
#  ('Tuck', 'male'),
#  ('Weidar', 'male'),
#  ('Olle', 'male'),
#  ('Gretel', 'female'),
#  ('Fanchon', 'female'),
#  ('Elga', 'female'),
#  ('Farley', 'male'),
#  ('Giffard', 'male'),
#  ('Skipton', 'male'),
#  ('Thorndike', 'male'),
#  ('Zebedee', 'male'),
#  ('Cindelyn', 'female'),
#  ('Venita', 'female'),
#  ('Rora', 'female'),
#  ('Shelley', 'female'),
#  ('Reilly', 'male'),
#  ('Sashenka', 'female'),
#  ('Udell', 'male'),
#  ('Corabella', 'female'),
#  ('Leighton', 'male'),
#  ('Lidia', 'female'),
#  ('Nico', 'male'),
#  ('Meris', 'female'),
#  ('Stephanie', 'female'),
#  ('Tilda', 'female'),
#  ('Arturo', 'male'),
#  ('Gwenette', 'female'),
#  ('Pace', 'male'),
#  ('Ivett', 'female'),
#  ('Nils', 'male'),
#  ('Halli', 'female'),
#  ('Niels', 'male'),
#  ('Aviva', 'female'),
#  ('Mignon', 'female'),
#  ('Thibaud', 'male'),
#  ('Eugenie', 'female'),
#  ('Yoko', 'female'),
#  ('Cathyleen', 'female'),
#  ('Corina', 'female'),
#  ('Meridith', 'female'),
#  ('Clarissa', 'female'),
#  ('Sheila-Kathryn', 'female'),
#  ('Harley', 'male'),
#  ('Aimil', 'female'),
#  ('Isa', 'male'),
#  ('Florencia', 'female'),
#  ('Fran', 'male'),
#  ('Odetta', 'female'),
#  ('Fayth', 'female'),
#  ('Voltaire', 'male'),
#  ('Diahann', 'female'),
#  ('Barde', 'male'),
#  ('Nonie', 'female'),
#  ('Sarah', 'female'),
#  ('Daniel', 'male'),
#  ('Lilas', 'female'),
#  ('Ailene', 'female'),
#  ('Oscar', 'male'),
#  ('Jedediah', 'male'),
#  ('Benji', 'male'),
#  ('Karlyn', 'female'),
#  ('Micah', 'male'),
#  ('Viviene', 'female'),
#  ('Caryl', 'female'),
#  ('Ladonna', 'female'),
#  ('Emmalynn', 'female'),
#  ('Annamari', 'female'),
#  ('Prescott', 'male'),
#  ('Jennilee', 'female'),
#  ('Jeremie', 'male'),
#  ('Hillery', 'male'),
#  ('Fenelia', 'female'),
#  ('Shelby', 'female'),
#  ('Alexei', 'male'),
#  ('Dillon', 'male'),
#  ('Lucila', 'female'),
#  ('Hallie', 'female'),
#  ('Michaeline', 'female'),
#  ('Juanita', 'female'),
#  ('Hilarie', 'female'),
#  ('Dorie', 'female'),
#  ('Nyssa', 'female'),
#  ('Lesli', 'female'),
#  ('Zea', 'female'),
#  ('Karoline', 'female'),
#  ('Doe', 'female'),
#  ('Walsh', 'male'),
#  ('Marilyn', 'female'),
#  ('Duffie', 'male'),
#  ('Gallagher', 'male'),
#  ('Johny', 'male'),
#  ('Myrta', 'female'),
#  ('Jef', 'male'),
#  ('Veradis', 'female'),
#  ('Shoshana', 'female'),
#  ('Cathleen', 'female'),
#  ('Dani', 'male'),
#  ('Vergil', 'male'),
#  ('Hadria', 'female'),
#  ('Brit', 'female'),
#  ('Constantia', 'female'),
#  ('Cinnamon', 'female'),
#  ('Morly', 'male'),
#  ('Laetitia', 'female'),
#  ('Waldo', 'male'),
#  ('Annalee', 'female'),
#  ('Roselia', 'female'),
#  ('Rita', 'female'),
#  ('Elora', 'female'),
#  ('Esmeralda', 'female'),
#  ('Hillard', 'male'),
#  ('Merralee', 'female'),
#  ('Danny', 'female'),
#  ('Lamar', 'male'),
#  ('Torrey', 'male'),
#  ('Shauna', 'female'),
#  ('Rozina', 'female'),
#  ('Lanette', 'female'),
#  ('Gabey', 'female'),
#  ('Charmian', 'female'),
#  ('Zelig', 'male'),
#  ('Secunda', 'female'),
#  ('Oral', 'male'),
#  ('Roselyn', 'female'),
#  ('Nicholas', 'male'),
#  ('Jessalyn', 'female'),
#  ('Berrie', 'female'),
#  ('Kamilah', 'female'),
#  ('Gavin', 'male'),
#  ('Una', 'female'),
#  ('Ferdinand', 'male'),
#  ('Vivianna', 'female'),
#  ('Julienne', 'female'),
#  ('Garv', 'male'),
#  ('Harold', 'male'),
#  ('Dahlia', 'female'),
#  ('Babara', 'female'),
#  ('Ric', 'male'),
#  ('Danyette', 'female'),
#  ('Orin', 'male'),
#  ('Ebony', 'female'),
#  ('Nealson', 'male'),
#  ('Robb', 'male'),
#  ('Cletus', 'male'),
#  ('Christalle', 'female'),
#  ('Brett', 'female'),
#  ('Nydia', 'female'),
#  ('Emmery', 'male'),
#  ('Agace', 'female'),
#  ('Perri', 'female'),
#  ('Hamlen', 'male'),
#  ('Joao', 'male'),
#  ('Isobel', 'female'),
#  ('Peggy', 'female'),
#  ('Valencia', 'female'),
#  ('Adriaens', 'female'),
#  ('Marylinda', 'female'),
#  ('Corrina', 'female'),
#  ('Bell', 'female'),
#  ('Georgiamay', 'female'),
#  ('Spence', 'male'),
#  ('Dominick', 'male'),
#  ('Lorene', 'female'),
#  ('Howie', 'male'),
#  ('Beverly', 'female'),
#  ('Evangelina', 'female'),
#  ('Rutger', 'male'),
#  ('Milli', 'female'),
#  ('Natasha', 'female'),
#  ('Esme', 'female'),
#  ('Roze', 'female'),
#  ('Arron', 'male'),
#  ('Dolley', 'female'),
#  ('Kaile', 'female'),
#  ('Jeana', 'female'),
#  ('Karin', 'female'),
#  ('Rayshell', 'female'),
#  ('Cobby', 'male'),
#  ('Gates', 'female'),
#  ('Dodie', 'female'),
#  ('Kimberlyn', 'female'),
#  ('Ebeneser', 'male'),
#  ('Lilly', 'female'),
#  ('Pia', 'female'),
#  ('Tandie', 'female'),
#  ('Claybourne', 'male'),
#  ('Francis', 'male'),
#  ('Elfreda', 'female'),
#  ('Monroe', 'male'),
#  ('Angie', 'male'),
#  ('Tadd', 'male'),
#  ('Bryan', 'male'),
#  ('Clint', 'male'),
#  ('Cindee', 'female'),
#  ('Natala', 'female'),
#  ('Rosa', 'female'),
#  ('Zorana', 'female'),
#  ('Ellette', 'female'),
#  ('Lilli', 'female'),
#  ('Gussie', 'female'),
#  ('Kevina', 'female'),
#  ('Mohan', 'male'),
#  ('Margi', 'female'),
#  ('Lin', 'male'),
#  ('Chrystal', 'female'),
#  ('Hannah', 'female'),
#  ('Matthus', 'male'),
#  ('Kyrstin', 'female'),
#  ('Stefanie', 'female'),
#  ('Anselm', 'male'),
#  ('Karen', 'female'),
#  ('Angele', 'female'),
#  ('Roscoe', 'male'),
#  ('Melony', 'female'),
#  ('Nolan', 'male'),
#  ('Conway', 'male'),
#  ('Donal', 'male'),
#  ('Chandler', 'male'),
#  ('Delphina', 'female'),
#  ('Ikey', 'male'),
#  ('Muffin', 'female'),
#  ('Freddy', 'male'),
#  ('Lilla', 'female'),
#  ('Fredericka', 'female'),
#  ('Rudy', 'male'),
#  ('Brynne', 'female'),
#  ('Leonidas', 'male'),
#  ('Cathryn', 'female'),
#  ('Patric', 'male'),
#  ('Jaquith', 'female'),
#  ('Giacomo', 'male'),
#  ('Sean', 'male'),
#  ...]

# %%
# Define feature extractor function
def gender_features(name):
    return {'suffix1': name[-1],
            'suffix2': name[-2:],
            'length': len(name)}

# Extract features from training set
train_set = [(gender_features(name), gender) for (name, gender) in train_names]
devtest_set = [(gender_features(name), gender) for (name, gender) in devtest_names]
test_set = [(gender_features(name), gender) for (name, gender) in test_names]

# Train Naive Bayes classifier
classifier = nltk.NaiveBayesClassifier.train(train_set)

# Test classifier on development testing set
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.758

# %%
# Define updated feature extractor function
def gender_features(name):
    return {'suffix1': name[-1],
            'suffix2': name[-2:],
            'length': len(name),
            'first_letter': name[0]}

# Extract features from training set
train_set = [(gender_features(name), gender) for (name, gender) in train_names]
devtest_set = [(gender_features(name), gender) for (name, gender) in devtest_names]
test_set = [(gender_features(name), gender) for (name, gender) in test_names]

# Train Naive Bayes classifier
classifier = nltk.NaiveBayesClassifier.train(train_set)

# Test classifier on development testing set
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.78

# %%
# Test classifier on testing set
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.784
